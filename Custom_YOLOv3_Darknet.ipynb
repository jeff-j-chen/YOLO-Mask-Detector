# %% [markdown]
# # <font style="color:white">4. Download Data from Open Images Dataset</font>
# Given below is the script for downloading data from open images dataset.
#
# It downloads 2 files from Open Images.
#
# 1. **train-annotations-bbox.csv** contains the bounding box labels for all images present in the training data of Open Images
# 1. **class-descriptions-boxable.csv** contains the classes which have bounding box annotations available in the dataset.
#
# Using these 2 files we can get a list of all files corresponding to a particular class.
#
# You can specify which classes you want to download and it will download the data. One thing to note here is that YOLO expects the bounding boxes to be in a specific format as given below.
#
# ```
# <object-class> <x_center> <y_center> <width> <height>
# ```
#
# The first field object-class-id is an integer representing the class of the object. It ranges from 0 to (number of classes – 1). In our current case, since we have only one class of snowman, it is always set to 0.
#
# The second and third entry, center-x and center-y are respectively the x and y coordinates of the center of the bounding box, normalized (divided) by the image width and height respectively.
#
# The fourth and fifth entry, width and height are respectively the width and height of the bounding box, again normalized (divided) by the image width and height respectively.
#
# Let’s consider an example with the following notations:
# ```
# x – x-coordinate(in pixels) of the center of the bounding box
# y – y-coordinate(in pixels) of the center of the bounding box
# w – width(in pixels) of the bounding box
# h – height(in pixels) of the bounding box
# W – width(in pixels) of the whole image
# H – height(in pixels) of the whole image
# ```
# Then we compute the annotation values in the label files as follows:
# ```
# center-x = x / W
# center-y = y / H
# width = w / W
# height = h / H
# ```
# The above four entries are all floating point values between 0 to 1.
#
# Note that the 2nd and 3rd elements are centers and NOT the top/bottom left corners. This is different from most datasets available on the internet.
#
# Thus, we reformat the bounding boxes according to YOLO in the last line of code in the function below.
#
# **NOTE:** Downloading the data from aws takes considerable amount of time ( ~7 seconds per image ). Thus, we have provided a zip file for the dataset which you can download in the next cell. You can use the script to download other classes when you experiment further.

# %%
def download_open_images_data(classes=["Ambulance"],maxImages=500):
    import csv
    import subprocess
    import os,time

    # if not os.path.exists("train-annotations-bbox.csv"):
    #     print("Downloading annotation files. . .\n")
    #     !wget https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv
    #     !wget https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv
    
    # !pip install awscli &> /dev/null

    runMode = "train"
    dataPath = "OID-data"

    with open('class-descriptions-boxable.csv', mode='r') as infile:
        reader = csv.reader(infile)
        dict_list = {rows[1]:rows[0] for rows in reader}

    subprocess.run(['rm', '-rf', dataPath])
    subprocess.run([ 'mkdir', dataPath])

    for ind in range(0, len(classes)):
        
        className = classes[ind]
        print("Class " + str(ind) + " : " + className)

        commandStr = "grep " + dict_list[className] + " " + runMode + "-annotations-bbox.csv"
        print(commandStr)
        class_annotations = subprocess.run(commandStr.split(), stdout=subprocess.PIPE).stdout.decode('utf-8')
        class_annotations = class_annotations.splitlines()

        totalNumOfAnnotations = len(class_annotations)
        print("Total number of annotations : "+str(totalNumOfAnnotations))
        cnt = 0
        for line in class_annotations[0:min(maxImages,totalNumOfAnnotations)]:

            cnt = cnt + 1
            print("annotation count : " + str(cnt))
            lineParts = line.split(',')
            subprocess.run([ 'aws', 's3', '--no-sign-request', '--only-show-errors', 'cp', 's3://open-images-dataset/'+runMode+'/'+lineParts[0]+".jpg", dataPath + '/'+lineParts[0]+".jpg"])
            with open(dataPath + '/%s.txt'%(lineParts[0]),'a') as f:
                f.write(' '.join([str(ind),str((float(lineParts[5]) + float(lineParts[4]))/2), str((float(lineParts[7]) + float(lineParts[6]))/2), str(float(lineParts[5])-float(lineParts[4])),str(float(lineParts[7])-float(lineParts[6]))])+'\n')

# %%
classes = ["Ambulance"]
maxImages = 400

# %% [markdown]
# Uncomment the cell below if you want to download a new class. You can download the data using the cell below.

# %%
## It might ask you to restart runtime, but it is not required.
download_open_images_data(classes, maxImages)
# Out:
# Class 0 : Ambulance
# grep /m/012n7d train-annotations-bbox.csv
# Total number of annotations : 447
# annotation count : 1
# annotation count : 2
# annotation count : 3
# annotation count : 4
# annotation count : 5
# annotation count : 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb#ch0000014?line=0'>1</a> ## It might ask you to restart runtime, but it is not required.
# ----> <a href='vscode-notebook-cell:/home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb#ch0000014?line=1'>2</a> download_open_images_data(classes, maxImages)
#
# /home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb Cell 2' in download_open_images_data(classes, maxImages)
#      <a href='vscode-notebook-cell:/home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb#ch0000011?line=38'>39</a> print("annotation count : " + str(cnt))
#      <a href='vscode-notebook-cell:/home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb#ch0000011?line=39'>40</a> lineParts = line.split(',')
# ---> <a href='vscode-notebook-cell:/home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb#ch0000011?line=40'>41</a> subprocess.run([ 'aws', 's3', '--no-sign-request', '--only-show-errors', 'cp', 's3://open-images-dataset/'+runMode+'/'+lineParts[0]+".jpg", dataPath + '/'+lineParts[0]+".jpg"])
#      <a href='vscode-notebook-cell:/home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb#ch0000011?line=41'>42</a> with open(dataPath + '/%s.txt'%(lineParts[0]),'a') as f:
#      <a href='vscode-notebook-cell:/home/jeff/Documents/Code/Mask_Detector/Custom_YOLOv3_Darknet.ipynb#ch0000011?line=42'>43</a>     f.write(' '.join([str(ind),str((float(lineParts[5]) + float(lineParts[4]))/2), str((float(lineParts[7]) + float(lineParts[6]))/2), str(float(lineParts[5])-float(lineParts[4])),str(float(lineParts[7])-float(lineParts[6]))])+'\n')
#
# File /usr/lib/python3.9/subprocess.py:507, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     <a href='file:///usr/lib/python3.9/subprocess.py?line=504'>505</a> with Popen(*popenargs, **kwargs) as process:
#     <a href='file:///usr/lib/python3.9/subprocess.py?line=505'>506</a>     try:
# --> <a href='file:///usr/lib/python3.9/subprocess.py?line=506'>507</a>         stdout, stderr = process.communicate(input, timeout=timeout)
#     <a href='file:///usr/lib/python3.9/subprocess.py?line=507'>508</a>     except TimeoutExpired as exc:
#     <a href='file:///usr/lib/python3.9/subprocess.py?line=508'>509</a>         process.kill()
#
# File /usr/lib/python3.9/subprocess.py:1126, in Popen.communicate(self, input, timeout)
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1123'>1124</a>         stderr = self.stderr.read()
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1124'>1125</a>         self.stderr.close()
# -> <a href='file:///usr/lib/python3.9/subprocess.py?line=1125'>1126</a>     self.wait()
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1126'>1127</a> else:
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1127'>1128</a>     if timeout is not None:
#
# File /usr/lib/python3.9/subprocess.py:1189, in Popen.wait(self, timeout)
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1186'>1187</a>     endtime = _time() + timeout
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1187'>1188</a> try:
# -> <a href='file:///usr/lib/python3.9/subprocess.py?line=1188'>1189</a>     return self._wait(timeout=timeout)
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1189'>1190</a> except KeyboardInterrupt:
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1190'>1191</a>     # https://bugs.python.org/issue25942
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1191'>1192</a>     # The first keyboard interrupt waits briefly for the child to
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1192'>1193</a>     # exit under the common assumption that it also received the ^C
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1193'>1194</a>     # generated SIGINT and will exit rapidly.
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1194'>1195</a>     if timeout is not None:
#
# File /usr/lib/python3.9/subprocess.py:1917, in Popen._wait(self, timeout)
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1914'>1915</a> if self.returncode is not None:
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1915'>1916</a>     break  # Another thread waited.
# -> <a href='file:///usr/lib/python3.9/subprocess.py?line=1916'>1917</a> (pid, sts) = self._try_wait(0)
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1917'>1918</a> # Check the pid and loop as waitpid has been known to
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1918'>1919</a> # return 0 even without WNOHANG in odd situations.
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1919'>1920</a> # http://bugs.python.org/issue14396.
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1920'>1921</a> if pid == self.pid:
#
# File /usr/lib/python3.9/subprocess.py:1875, in Popen._try_wait(self, wait_flags)
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1872'>1873</a> """All callers to this function MUST hold self._waitpid_lock."""
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1873'>1874</a> try:
# -> <a href='file:///usr/lib/python3.9/subprocess.py?line=1874'>1875</a>     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1875'>1876</a> except ChildProcessError:
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1876'>1877</a>     # This happens if SIGCLD is set to be ignored or waiting
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1877'>1878</a>     # for child processes has otherwise been disabled for our
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1878'>1879</a>     # process.  This child is dead, we can't get the status.
#    <a href='file:///usr/lib/python3.9/subprocess.py?line=1879'>1880</a>     pid = self.pid
#
# KeyboardInterrupt:

# %% [markdown]
# ## <font style="color:white">4.1. Download Data</font>
# Download the data which we have shared using the dropbox link. This is a faster way. You can use the above process for downloading any other category.

# %%
# !wget "https://www.dropbox.com/s/84jr6gxlvrw3azy/OID-data.zip?dl=1" -O OID-data.zip
# !unzip -o OID-data.zip &> /dev/null
# Out:
# --2022-04-18 09:14:38--  https://www.dropbox.com/s/84jr6gxlvrw3azy/OID-data.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/84jr6gxlvrw3azy/OID-data.zip [following]
# --2022-04-18 09:14:39--  https://www.dropbox.com/s/dl/84jr6gxlvrw3azy/OID-data.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1d5ee66459fb72e399f3beb508.dl.dropboxusercontent.com/cd/0/get/Bjrmb6NobJIYbnD5K_rrgDCrYFao7KGLszu9EKlb9DeqBlt_-uxYOqi_6BwIm4avtadUaXctDY6L4Z3MFVGbX27T-qIYfQFLdAcycHKg6M37MO6EbX700sPt250ca95zW_6c9OtxpkZHR9V0zYdnAd1ajH4gwIOM7RJZ4sNA04q49pJRhXE0Gg_MpzEUc2HL7bg/file?dl=1# [following]
# --2022-04-18 09:14:39--  https://uc1d5ee66459fb72e399f3beb508.dl.dropboxusercontent.com/cd/0/get/Bjrmb6NobJIYbnD5K_rrgDCrYFao7KGLszu9EKlb9DeqBlt_-uxYOqi_6BwIm4avtadUaXctDY6L4Z3MFVGbX27T-qIYfQFLdAcycHKg6M37MO6EbX700sPt250ca95zW_6c9OtxpkZHR9V0zYdnAd1ajH4gwIOM7RJZ4sNA04q49pJRhXE0Gg_MpzEUc2HL7bg/file?dl=1
# Resolving uc1d5ee66459fb72e399f3beb508.dl.dropboxusercontent.com (uc1d5ee66459fb72e399f3beb508.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6017:15::a27d:20f
# Connecting to uc1d5ee66459fb72e399f3beb508.dl.dropboxusercontent.com (uc1d5ee66459fb72e399f3beb508.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116188863 (111M) [application/binary]
# Saving to: ‘OID-data.zip’
#
# OID-data.zip        100%[===================>] 110.81M  7.54MB/s    in 19s
#
# 2022-04-18 09:15:00 (5.95 MB/s) - ‘OID-data.zip’ saved [116188863/116188863]

# %% [markdown]
# ## <font style="color:white">4.2. Prepare dataset files</font>
# We need to create a txt file which contains the path to the images. These files will be used while setting up the training.
#
# The data is split into train and test in the ratio of 80:20. So, we will use 80% of the data for training and the rest for testing after a few iterations of training.

# %%
import random
import os
import subprocess
import sys

image_dir = "./OID-data"
f_val = open("data_test.txt", 'w')
f_train = open("data_train.txt", 'w')

path, dirs, files = next(os.walk(image_dir))
data_size = len(files)

ind = 0
data_test_size = int(0.2 * data_size)
test_array = random.sample(range(data_size), k=data_test_size)

for f in os.listdir(image_dir):
    if(f.split(".")[-1] == "jpg"):
        ind += 1
        
        if ind in test_array:
            f_val.write(image_dir+'/'+f+'\n')
        else:
            f_train.write(image_dir+'/'+f+'\n')

f_train.close()
f_val.close()

# %% [markdown]
# # <font style="color:white">5. Download Code for YOLO Training</font>
# We have shared the code for training in the link below. Explanation of each file follows next.

# %%
# !wget "https://www.dropbox.com/sh/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa?dl=1" -O yolov3-ambulance-code.zip
# !unzip -o yolov3-ambulance-code.zip
# Out:
# --2022-04-18 09:15:30--  https://www.dropbox.com/sh/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/dl/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa [following]
# --2022-04-18 09:15:36--  https://www.dropbox.com/sh/dl/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc536cc027647a2dde9b4aa317e4.dl.dropboxusercontent.com/zip_download_get/BHDnZ_OcDmfArWgkm0q5ODLxlWKxzMUiYTchUMuzyrxYO0z5MT-7vPrG6IaSagqwVjtZ4-DolU0JaGyps-Pb53sMgQ93ToZ7bb3rA0cf8XFJ8g?dl=1# [following]
# --2022-04-18 09:15:36--  https://uc536cc027647a2dde9b4aa317e4.dl.dropboxusercontent.com/zip_download_get/BHDnZ_OcDmfArWgkm0q5ODLxlWKxzMUiYTchUMuzyrxYO0z5MT-7vPrG6IaSagqwVjtZ4-DolU0JaGyps-Pb53sMgQ93ToZ7bb3rA0cf8XFJ8g?dl=1
# Resolving uc536cc027647a2dde9b4aa317e4.dl.dropboxusercontent.com (uc536cc027647a2dde9b4aa317e4.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6017:15::a27d:20f
# Connecting to uc536cc027647a2dde9b4aa317e4.dl.dropboxusercontent.com (uc536cc027647a2dde9b4aa317e4.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17639 (17K) [application/zip]
# Saving to: ‘yolov3-ambulance-code.zip’
#
# yolov3-ambulance-co 100%[===================>]  17.23K   110KB/s    in 0.2s
#
# 2022-04-18 09:15:37 (110 KB/s) - ‘yolov3-ambulance-code.zip’ saved [17639/17639]
#
# Archive:  yolov3-ambulance-code.zip
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
#  extracting: class.names
#  extracting: yolov3-ambulance-test.cfg
#  extracting: yolov3-ambulance-train.cfg
#  extracting: yolov3-ambulance-setup.data

# %% [markdown]
# You can see there are 4 files which have been downloaded. We will go through each file in the next section.

# %% [markdown]
# # <font style="color:white">6. Download weights for Convolutional backbone</font>
# When you train your own object detector, it is a good idea to leverage existing models trained on very large datasets even though the large dataset may not contain the object you are trying to detect. This process is called transfer learning.
#
# Instead of learning from scratch, we use a pre-trained model which contains convolutional weights trained on ImageNet. Using these weights as our starting weights, our network can learn faster. We will use the pre-trained convolutional backbone.
#
# We will download the weights file from our server as the author's server seemed slow. If you face any issues, you can download the file from the link given in the code below.

# %%
# Original File : https://pjreddie.com/media/files/darknet53.conv.74
# !wget "https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1" -O darknet53.conv.74
# Out:
# --2022-04-18 09:18:39--  https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/18dwbfth7prbf0h/darknet53.conv.74 [following]
# --2022-04-18 09:18:39--  https://www.dropbox.com/s/dl/18dwbfth7prbf0h/darknet53.conv.74
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com/cd/0/get/BjrKDqk7PxYFq_GsZRlW0vNNfr8E5sftY37Sf2YAncq5rcD7nPVGgBXj8hOS_3aVDV_-ikomNzNNeRR_O0f7YOaUbGUeA7q1Tzgw9MZWrG9C5llVHDdLtS15spHKVEUNyqNO67ru1v-4Pbvv-hVHalYWBuusLqPrkiVnNMIDDZHhg4HZKFrRcDiFB2lpLBQAVU8/file?dl=1# [following]
# --2022-04-18 09:18:40--  https://uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com/cd/0/get/BjrKDqk7PxYFq_GsZRlW0vNNfr8E5sftY37Sf2YAncq5rcD7nPVGgBXj8hOS_3aVDV_-ikomNzNNeRR_O0f7YOaUbGUeA7q1Tzgw9MZWrG9C5llVHDdLtS15spHKVEUNyqNO67ru1v-4Pbvv-hVHalYWBuusLqPrkiVnNMIDDZHhg4HZKFrRcDiFB2lpLBQAVU8/file?dl=1
# Resolving uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com (uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6017:15::a27d:20f
# Connecting to uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com (uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/binary]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  21.5MB/s    in 8.4s
#
# 2022-04-18 09:18:49 (18.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # <font style="color:white">7. Training Configuration</font>
# As explained in the theory section, we will use the config file to specify the various training parameters. A gist of all the parameters is given below:
#
# ## <font style="color:white">7.1. Data Setup</font>
# In the file **`yolov3-ambulance-setup.data`**(included in our code), we need to provide information about the specifications for our object detector and some relevant paths.
#
# The contents of the file are as follows:
# ```
# classes = 1
# train  = data_train.txt
# valid  = data_test.txt
# names = class.names
# backup = backup/
# ```
# The classes parameter needs the number of classes. In our case, it is 1.
#
# You need to provide the absolute paths of the files **`data_train.txt`** and **`data_test.txt`** generated earlier, which have the list of files to be used for training(train parameter) and validation(valid parameter) respectively.
#
# The names field represents the path of a file which contains the names of all the classes. We have included the **`class.names`** file which contains the class name **`Ambulance`**. You will need to provide its absolute path in your machine here.
#
# Lastly, for the **`backup`** parameter, we need to give the path to an existing directory where we can store the intermediate weights files as the training progresses.
#
# ## <font style="color:white">7.2. Training Config File</font>
# Along with the yolov3-ambulance-setup.data and class.names files, YOLOv3 also needs a configuration file **`yolov3-ambulance-train.cfg`**. It is based on the demo configuration file, yolov3-voc.cfg (comes with darknet code), which was used to train on the VOC dataset. All the important training parameters are stored in this configuration file. Let us understand what they mean and what values to set them to.
#
# ### <font style="color:green">7.2.1 Batch hyper-parameter in YOLOv3</font>
# Let’s learn more about batch and subdivision parameter.
# ```
# [net]
# # Testing
# # batch=1
# # subdivisions=1
# # Training
# batch=64
# subdivisions=16
# ```
# The batch parameter indicates the batch size used during training.
#
# Our training set contains a few hundred images, but it is not uncommon to train on million of images. The training process involves iteratively updating the weights of the neural network based on how many mistakes it is making on the training dataset.
#
# It is impractical (and unnecessary) to use all images in the training set at once to update the weights. So, a small subset of images is used in one iteration, and this subset is called the batch size.
#
# When the batch size is set to 64, it means 64 images are used in one iteration to update the parameters of the neural network.
#
# ### <font style="color:green">7.2.2 Subdivisions configuration parameter in YOLOv3</font>
# Even though you may want to use a batch size of 64 for training your neural network, you may not have a GPU with enough memory to use a batch size of 64. Fortunately, Darknet allows you to specify a variable called subdivisions that lets you process a fraction of the batch size at one time on your GPU.
#
# You can start the training with subdivisions=1, and if you get an Out of memory error, increase the subdivisions parameter by multiples of 2(e.g. 2, 4, 8, 16) till the training proceeds successfully. The GPU will process batch/subdivision number of images at any time, but the full batch or iteration would be complete only after all the 64 (as set above) images are processed.
#
# During testing, both batch and subdivision are set to 1.
#
# ### <font style="color:green">7.2.3 Width, Height, Channels</font>
# These configuration parameters specify the input image size and the number of channels.
#
# ```
# width=416
# height=416
# channels=3
# ```
# The input training images are first resized to width x height before training. Here we use the default values of 416×416. The results might improve if we increase it to 608×608, but it would take longer to train too. channels=3 indicates that we would be processing 3-channel RGB input images.
#
# ### <font style="color:green">7.2.4 Momentum and Decay</font>
# The configuration file contains a few parameters that control how the weight is updated.
# ```
# momentum=0.9
# decay=0.0005
# ```
# In the previous section, we mentioned how the weights of a neural network are updated based on a small batch of images and not the entire dataset. Because of this reason, the weight updates fluctuate quite a bit. That is why a parameter momentum is used to penalize large weight changes between iterations.
#
# A typical neural network has millions of weights and therefore they can easily overfit any training data. Overfitting simply means it will do very well on training data and poorly on test data. It is almost like the neural network has memorized the answer to all images in the training set, but really not learned the underlying concept. One of the ways to mitigate this problem is to penalize large value for weights. The parameter decay controls this penalty term. The default value works just fine, but you may want to tweak this if you notice overfitting.
#
# ### <font style="color:green">7.2.5 Learning Rate, Steps, Scales, Burn In (warm-up)</font>
# ```
# learning_rate=0.001
# policy=steps
# steps=800
# scales=.1
# burn_in=100
# ```
# The parameter learning rate controls how aggressively we should learn based on the current batch of data. Typically this is a number between 0.01 and 0.0001.
#
# At the beginning of the training process, we are starting with zero information and so the learning rate needs to be high. But as the neural network sees a lot of data, the weights need to change less aggressively. In other words, the learning rate needs to be decreased over time. In the configuration file, this decrease in learning rate is accomplished by first specifying that our learning rate decreasing policy is steps. In the above example, the learning rate will start from 0.001 and remain constant for 800 iterations, and then it will multiply by scales to get the new learning rate. We could have also specified multiple steps and scales.
#
# In the previous paragraph, we mentioned that the learning rate needs to be high in the beginning and low later on. While that statement is largely true, it has been empirically found that the training speed tends to increase if we have a lower learning rate for a short period of time at the very beginning. This is controlled by the burn_in parameter. Sometimes this **`burn-in`** period is also called warm-up period.
#
# ### <font style="color:green">7.2.6 Data augmentation</font>
# We know data collection takes a long time and it is difficult to find high quality annotated data. We want to make maximum use of this data by cooking up new data. This process is called data augmentation. For example, an image of the ambulance rotated by 5 degrees is still an image of a ambulance. The angle parameter in the configuration file allows you to randomly rotate the given image by ± angle.
#
# Similarly, if we transform the colors of the entire picture using saturation, exposure, and hue, it is still a picture of the ambulance.
# ```
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# ```
# We used the default values for training.
#
# ### <font style="color:green">7.2.7 Number of iterations</font>
# Finally, we need to specify how many iterations should the training process be run for.
# ```
# max_batches=1000
# ```
#
# For multi-class object detectors, the max_batches number is higher, i.e. we need to run for more number of batches(e.g. in yolov3-voc.cfg). For an n-classes object detector, it is advisable to run the training for at least 2000*n batches. In our case with only 1 class, 1000 seemed like a safe number for max_batches.
#
# You should try to change the parameter and see how it performs.
#
# ### <font style="color:green">7.2.8 Change filters parameter in conv layers [Important for multiple objects]</font>
# Change the filters parameter in the convolutional layer just before the yolo layer according to the formula
#
# **`filters=( classes + 5 ) * 3`**
#
# Since we are using classes = 1, thus, #filters in our case is 18. You should make this change if you are dealing with more classes.
#
#
# ## <font color="white">7.3. Names file </font>
# We need to specify the names of the classes in the **`.names`** file. In our case, there is only 1 class and thus, only Ambulance is added to that file.

# %% [markdown]
# # <font style="color:white">8. Start Training </font>
# For starting training using darknet, we need to execute the following command. Here we are specifying the
# 1. path to the setup file,
# 1. path to config file,
# 1. path to convolutional weights file
#
# and also passing some flags such as:
#
# - **`dont_show`** which wont display the graphs. This is required for Colab since it does not have a display and it will crash if it tries to display, not if you run the notebook on your local system.
# - **`map`** - this will calculate mAP - mean average precision for the test data which we have specified using the data_test.txt file which contains 20% of our data.

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector train yolov3-ambulance-setup.data yolov3-ambulance-train.cfg ./darknet53.conv.74 -map 2> train_log.txt
# Out:
#  Prepare additional network for mAP calculation...
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# yolov3-ambulance-train
# net.optimized_memory = 0
# mini_batch = 2, batch = 64, time_steps = 1, train = 1
#
#  seen 64, trained: 0 K-images (0 Kilo-batches_64)
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
#  If error occurs - run training with flag: -dont_show
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 164.41 MB
#  CUDA allocate done!
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 100 iterations)
#  1: 7246.750488, 7246.750488 avg loss, 0.001000 rate, 31.126220 seconds, 64 images, -1.000000 hours left
# Loaded: 0.000173 seconds
#
#  (next mAP calculation at 100 iterations)
#  2: 1.837421, 6522.259277 avg loss, 0.001000 rate, 30.612484 seconds, 128 images, 8.637559 hours left
# Loaded: 0.000374 seconds
#
#  (next mAP calculation at 100 iterations)
#  3: 1.911756, 5870.224609 avg loss, 0.001000 rate, 29.434335 seconds, 192 images, 8.636049 hours left
# Loaded: 0.000439 seconds
#
#  (next mAP calculation at 100 iterations)
#  4: 2.653409, 5283.467285 avg loss, 0.001000 rate, 29.255145 seconds, 256 images, 8.631206 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 100 iterations)
#  5: 1.130373, 4755.233398 avg loss, 0.001000 rate, 29.896256 seconds, 320 images, 8.625835 hours left
# Loaded: 0.000204 seconds
#
#  (next mAP calculation at 100 iterations)
#  6: 0.904666, 4279.800293 avg loss, 0.001000 rate, 30.030313 seconds, 384 images, 8.622207 hours left
# Loaded: 0.000595 seconds
#
#  (next mAP calculation at 100 iterations)
#  7: 1.236874, 3851.943848 avg loss, 0.001000 rate, 30.185115 seconds, 448 images, 8.618902 hours left
# Loaded: 0.000210 seconds
#
#  (next mAP calculation at 100 iterations)
#  8: 0.865454, 3466.835938 avg loss, 0.001000 rate, 29.951901 seconds, 512 images, 8.615976 hours left
# Loaded: 0.000177 seconds
#
#  (next mAP calculation at 100 iterations)
#  9: 1.073729, 3120.259766 avg loss, 0.001000 rate, 30.642543 seconds, 576 images, 8.612351 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 100 iterations)
#  10: 0.726943, 2808.306396 avg loss, 0.001000 rate, 29.994304 seconds, 640 images, 8.610580 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 100 iterations)
#  11: 0.979420, 2527.573730 avg loss, 0.001000 rate, 10.765249 seconds, 704 images, 8.606959 hours left
# Loaded: 0.000532 seconds
#
#  (next mAP calculation at 100 iterations)
#  12: 1.155258, 2274.931885 avg loss, 0.001000 rate, 12.854058 seconds, 768 images, 8.550464 hours left
# Loaded: 0.000202 seconds
#
#  (next mAP calculation at 100 iterations)
#  13: 1.111874, 2047.549927 avg loss, 0.001000 rate, 12.492955 seconds, 832 images, 8.500239 hours left
# Loaded: 0.000442 seconds
#
#  (next mAP calculation at 100 iterations)
#  14: 0.881284, 1842.883057 avg loss, 0.001000 rate, 12.825823 seconds, 896 images, 8.449488 hours left
# Loaded: 0.000294 seconds
#
#  (next mAP calculation at 100 iterations)
#  15: 1.031225, 1658.697876 avg loss, 0.001000 rate, 11.615160 seconds, 960 images, 8.400124 hours left
# Loaded: 0.000448 seconds
#
#  (next mAP calculation at 100 iterations)
#  16: 1.478979, 1492.975952 avg loss, 0.001000 rate, 12.296127 seconds, 1024 images, 8.347904 hours left
# Loaded: 0.000440 seconds
#
#  (next mAP calculation at 100 iterations)
#  17: 0.776379, 1343.755981 avg loss, 0.001000 rate, 9.837339 seconds, 1088 images, 8.298036 hours left
# Loaded: 0.000433 seconds
#
#  (next mAP calculation at 100 iterations)
#  18: 0.766670, 1209.457031 avg loss, 0.001000 rate, 8.525054 seconds, 1152 images, 8.241918 hours left
# Loaded: 0.000160 seconds
#
#  (next mAP calculation at 100 iterations)
#  19: 1.060911, 1088.617432 avg loss, 0.001000 rate, 12.929156 seconds, 1216 images, 8.182754 hours left
# Loaded: 0.000238 seconds
#
#  (next mAP calculation at 100 iterations)
#  20: 0.902250, 979.845886 avg loss, 0.001000 rate, 14.771140 seconds, 1280 images, 8.136160 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 100 iterations)
#  21: 0.762586, 881.937561 avg loss, 0.001000 rate, 14.415333 seconds, 1344 images, 8.095009 hours left
# Loaded: 0.000502 seconds
#
#  (next mAP calculation at 100 iterations)
#  22: 1.068811, 793.850708 avg loss, 0.001000 rate, 13.490969 seconds, 1408 images, 8.053261 hours left
# Loaded: 0.000167 seconds
#
#  (next mAP calculation at 100 iterations)
#  23: 1.165404, 714.582153 avg loss, 0.001000 rate, 11.748495 seconds, 1472 images, 8.009381 hours left
# Loaded: 0.000464 seconds
#
#  (next mAP calculation at 100 iterations)
#  24: 0.891837, 643.213135 avg loss, 0.001000 rate, 12.126664 seconds, 1536 images, 7.961172 hours left
# Loaded: 0.000182 seconds
#
#  (next mAP calculation at 100 iterations)
#  25: 0.714490, 578.963257 avg loss, 0.001000 rate, 9.313439 seconds, 1600 images, 7.914438 hours left
# Loaded: 0.000172 seconds
#
#  (next mAP calculation at 100 iterations)
#  26: 0.706628, 521.137573 avg loss, 0.001000 rate, 14.872660 seconds, 1664 images, 7.860518 hours left
# Loaded: 0.000398 seconds
#
#  (next mAP calculation at 100 iterations)
#  27: 0.756254, 469.099426 avg loss, 0.001000 rate, 11.839314 seconds, 1728 images, 7.822153 hours left
# Loaded: 0.000398 seconds
#
#  (next mAP calculation at 100 iterations)
#  28: 6.104813, 422.799957 avg loss, 0.001000 rate, 12.501107 seconds, 1792 images, 7.775931 hours left
# Loaded: 0.000125 seconds
#
#  (next mAP calculation at 100 iterations)
#  29: 1.426811, 380.662628 avg loss, 0.001000 rate, 13.465450 seconds, 1856 images, 7.731926 hours left
# Loaded: 0.000178 seconds
#
#  (next mAP calculation at 100 iterations)
#  30: 0.955171, 342.691895 avg loss, 0.001000 rate, 13.609852 seconds, 1920 images, 7.690927 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 100 iterations)
#  31: 0.868910, 308.509583 avg loss, 0.001000 rate, 13.323044 seconds, 1984 images, 7.650689 hours left
# Loaded: 0.000184 seconds
#
#  (next mAP calculation at 100 iterations)
#  32: 2.490625, 277.907684 avg loss, 0.001000 rate, 11.633957 seconds, 2048 images, 7.610044 hours left
# Loaded: 0.000535 seconds
#
#  (next mAP calculation at 100 iterations)
#  33: 0.937311, 250.210648 avg loss, 0.001000 rate, 12.197515 seconds, 2112 images, 7.565226 hours left
# Loaded: 0.000545 seconds
#
#  (next mAP calculation at 100 iterations)
#  34: 6.815322, 225.871109 avg loss, 0.001000 rate, 11.182299 seconds, 2176 images, 7.522340 hours left
# Loaded: 0.000245 seconds
#
#  (next mAP calculation at 100 iterations)
#  35: 7.654077, 204.049408 avg loss, 0.001000 rate, 14.434187 seconds, 2240 images, 7.477124 hours left
# Loaded: 0.000095 seconds
#
#  (next mAP calculation at 100 iterations)
#  36: 3.497159, 183.994186 avg loss, 0.001000 rate, 7.487053 seconds, 2304 images, 7.441045 hours left
# Loaded: 0.000440 seconds
#
#  (next mAP calculation at 100 iterations)
#  37: 37.509785, 169.345749 avg loss, 0.001000 rate, 11.543165 seconds, 2368 images, 7.386684 hours left
# Loaded: 0.000367 seconds
#
#  (next mAP calculation at 100 iterations)
#  38: 2.228099, 152.633987 avg loss, 0.001000 rate, 12.627042 seconds, 2432 images, 7.343696 hours left
# Loaded: 0.000408 seconds
#
#  (next mAP calculation at 100 iterations)
#  39: 4.681782, 137.838760 avg loss, 0.001000 rate, 12.540857 seconds, 2496 images, 7.304003 hours left
# Loaded: 0.000219 seconds
#
#  (next mAP calculation at 100 iterations)
#  40: 1.791545, 124.234039 avg loss, 0.001000 rate, 12.493843 seconds, 2560 images, 7.264441 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 68.42 MB
#  CUDA allocate done!
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 100 iterations)
#  41: 1.254978, 111.936134 avg loss, 0.001000 rate, 12.738730 seconds, 2624 images, 7.225114 hours left
# Loaded: 0.000200 seconds
#
#  (next mAP calculation at 100 iterations)
#  42: 0.911345, 100.833656 avg loss, 0.001000 rate, 13.164576 seconds, 2688 images, 7.186798 hours left
# Loaded: 0.000394 seconds
#
#  (next mAP calculation at 100 iterations)
#  43: 0.805419, 90.830833 avg loss, 0.001000 rate, 13.989458 seconds, 2752 images, 7.149963 hours left
# Loaded: 0.000110 seconds
#
#  (next mAP calculation at 100 iterations)
#  44: 0.999433, 81.847694 avg loss, 0.001000 rate, 12.151070 seconds, 2816 images, 7.115653 hours left
# Loaded: 0.000093 seconds
#
#  (next mAP calculation at 100 iterations)
#  45: 1.663903, 73.829315 avg loss, 0.001000 rate, 13.794291 seconds, 2880 images, 7.076765 hours left
# Loaded: 0.000081 seconds
#
#  (next mAP calculation at 100 iterations)
#  46: 7.608096, 67.207191 avg loss, 0.001000 rate, 13.705104 seconds, 2944 images, 7.042591 hours left
# Loaded: 0.000399 seconds
#
#  (next mAP calculation at 100 iterations)
#  47: 8.442613, 61.330734 avg loss, 0.001000 rate, 13.229194 seconds, 3008 images, 7.008484 hours left
# Loaded: 0.000207 seconds
#
#  (next mAP calculation at 100 iterations)
#  48: 3.877738, 55.585434 avg loss, 0.001000 rate, 14.291732 seconds, 3072 images, 6.973421 hours left
# Loaded: 0.000286 seconds
#
#  (next mAP calculation at 100 iterations)
#  49: 2.364676, 50.263359 avg loss, 0.001000 rate, 15.110984 seconds, 3136 images, 6.941482 hours left
# Loaded: 0.000172 seconds
#
#  (next mAP calculation at 100 iterations)
#  50: 2.280278, 45.465050 avg loss, 0.001000 rate, 12.522165 seconds, 3200 images, 6.911986 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 47.89 MB
#  CUDA allocate done!
# Loaded: 0.430657 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 100 iterations)
#  51: 3.339061, 41.252449 avg loss, 0.001000 rate, 13.822679 seconds, 3264 images, 6.875911 hours left
# Loaded: 0.000439 seconds
#
#  (next mAP calculation at 100 iterations)
#  52: 3.288785, 37.456081 avg loss, 0.001000 rate, 15.305528 seconds, 3328 images, 6.844726 hours left
# Loaded: 0.000172 seconds
#
#  (next mAP calculation at 100 iterations)
#  53: 0.870643, 33.797539 avg loss, 0.001000 rate, 14.045242 seconds, 3392 images, 6.816584 hours left
# Loaded: 0.000091 seconds
#
#  (next mAP calculation at 100 iterations)
#  54: 0.936390, 30.511423 avg loss, 0.001000 rate, 13.247518 seconds, 3456 images, 6.785366 hours left
# Loaded: 0.000392 seconds
#
#  (next mAP calculation at 100 iterations)
#  55: 1.134416, 27.573723 avg loss, 0.001000 rate, 13.755986 seconds, 3520 images, 6.752324 hours left
# Loaded: 0.000174 seconds
#
#  (next mAP calculation at 100 iterations)
#  56: 5.318943, 25.348246 avg loss, 0.001000 rate, 15.285171 seconds, 3584 images, 6.720912 hours left
# Loaded: 0.000258 seconds
#
#  (next mAP calculation at 100 iterations)
#  57: 0.970155, 22.910437 avg loss, 0.001000 rate, 14.782497 seconds, 3648 images, 6.693784 hours left
# Loaded: 0.000499 seconds
#
#  (next mAP calculation at 100 iterations)
#  58: 1.714719, 20.790865 avg loss, 0.001000 rate, 14.552837 seconds, 3712 images, 6.665569 hours left
# Loaded: 0.000167 seconds
#
#  (next mAP calculation at 100 iterations)
#  59: 6.687287, 19.380507 avg loss, 0.001000 rate, 14.073395 seconds, 3776 images, 6.636995 hours left
# Loaded: 0.000172 seconds
#
#  (next mAP calculation at 100 iterations)
#  60: 3.996650, 17.842121 avg loss, 0.001000 rate, 14.306209 seconds, 3840 images, 6.607412 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 68.42 MB
#  CUDA allocate done!
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 100 iterations)
#  61: 3.245701, 16.382479 avg loss, 0.001000 rate, 14.024650 seconds, 3904 images, 6.578694 hours left
# Loaded: 0.000108 seconds
#
#  (next mAP calculation at 100 iterations)
#  62: 2.635252, 15.007756 avg loss, 0.001000 rate, 13.334076 seconds, 3968 images, 6.549488 hours left
# Loaded: 0.000538 seconds
#
#  (next mAP calculation at 100 iterations)
#  63: 1.975123, 13.704493 avg loss, 0.001000 rate, 12.806455 seconds, 4032 images, 6.518736 hours left
# Loaded: 0.000488 seconds
#
#  (next mAP calculation at 100 iterations)
#  64: 0.863334, 12.420377 avg loss, 0.001000 rate, 14.365439 seconds, 4096 images, 6.486883 hours left
# Loaded: 0.000407 seconds
#
#  (next mAP calculation at 100 iterations)
#  65: 2.350766, 11.413416 avg loss, 0.001000 rate, 13.497598 seconds, 4160 images, 6.459365 hours left
# Loaded: 0.000462 seconds
#
#  (next mAP calculation at 100 iterations)
#  66: 1.065655, 10.378640 avg loss, 0.001000 rate, 12.478057 seconds, 4224 images, 6.429829 hours left
# Loaded: 0.000304 seconds
#
#  (next mAP calculation at 100 iterations)
#  67: 0.951670, 9.435944 avg loss, 0.001000 rate, 13.689566 seconds, 4288 images, 6.397906 hours left
# Loaded: 0.000108 seconds
#
#  (next mAP calculation at 100 iterations)
#  68: 2.746512, 8.767000 avg loss, 0.001000 rate, 13.726953 seconds, 4352 images, 6.369407 hours left
# Loaded: 0.000375 seconds
#
#  (next mAP calculation at 100 iterations)
#  69: 0.709137, 7.961214 avg loss, 0.001000 rate, 12.928026 seconds, 4416 images, 6.341251 hours left
# Loaded: 0.000568 seconds
#
#  (next mAP calculation at 100 iterations)
#  70: 1.385579, 7.303650 avg loss, 0.001000 rate, 13.959047 seconds, 4480 images, 6.311273 hours left
# Resizing, random_coef = 1.40
#
#  448 x 448
#  try to allocate additional workspace_size = 91.42 MB
#  CUDA allocate done!
# Loaded: 0.000113 seconds
#
#  (next mAP calculation at 100 iterations)
#  71: 0.838925, 6.657178 avg loss, 0.001000 rate, 15.334678 seconds, 4544 images, 6.284223 hours left
# Loaded: 0.000358 seconds
#
#  (next mAP calculation at 100 iterations)
#  72: 0.621212, 6.053581 avg loss, 0.001000 rate, 16.888979 seconds, 4608 images, 6.260953 hours left
# Loaded: 0.000113 seconds
#
#  (next mAP calculation at 100 iterations)
#  73: 3.180566, 5.766280 avg loss, 0.001000 rate, 18.735744 seconds, 4672 images, 6.241880 hours left
# Loaded: 0.000400 seconds
#
#  (next mAP calculation at 100 iterations)
#  74: 1.144061, 5.304058 avg loss, 0.001000 rate, 17.216831 seconds, 4736 images, 6.227707 hours left
# Loaded: 0.000469 seconds
#
#  (next mAP calculation at 100 iterations)
#  75: 0.843972, 4.858049 avg loss, 0.001000 rate, 18.480690 seconds, 4800 images, 6.209716 hours left
# Loaded: 0.000503 seconds
#
#  (next mAP calculation at 100 iterations)
#  76: 0.705720, 4.442816 avg loss, 0.001000 rate, 16.931919 seconds, 4864 images, 6.195106 hours left
# Loaded: 0.000466 seconds
#
#  (next mAP calculation at 100 iterations)
#  77: 0.727019, 4.071237 avg loss, 0.001000 rate, 15.457533 seconds, 4928 images, 6.176615 hours left
# Loaded: 0.000476 seconds
#
#  (next mAP calculation at 100 iterations)
#  78: 0.613145, 3.725427 avg loss, 0.001000 rate, 15.342226 seconds, 4992 images, 6.154481 hours left
# Loaded: 0.000091 seconds
#
#  (next mAP calculation at 100 iterations)
#  79: 0.924163, 3.445301 avg loss, 0.001000 rate, 17.288573 seconds, 5056 images, 6.132231 hours left
# Loaded: 0.000417 seconds
#
#  (next mAP calculation at 100 iterations)
#  80: 3.459576, 3.446728 avg loss, 0.001000 rate, 15.808676 seconds, 5120 images, 6.115139 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 101.06 MB
#  CUDA allocate done!
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 100 iterations)
#  81: 1.396991, 3.241755 avg loss, 0.001000 rate, 25.924775 seconds, 5184 images, 6.094389 hours left
# Loaded: 0.000539 seconds
#
#  (next mAP calculation at 100 iterations)
#  82: 0.719600, 2.989539 avg loss, 0.001000 rate, 25.359820 seconds, 5248 images, 6.099626 hours left
# Loaded: 0.000130 seconds
#
#  (next mAP calculation at 100 iterations)
#  83: 0.909226, 2.781508 avg loss, 0.001000 rate, 24.182228 seconds, 5312 images, 6.103298 hours left
# Loaded: 0.000500 seconds
#
#  (next mAP calculation at 100 iterations)
#  84: 0.690219, 2.572379 avg loss, 0.001000 rate, 24.753221 seconds, 5376 images, 6.103864 hours left
# Loaded: 0.000462 seconds
#
#  (next mAP calculation at 100 iterations)
#  85: 0.720589, 2.387200 avg loss, 0.001000 rate, 25.067097 seconds, 5440 images, 6.105810 hours left
# Loaded: 0.000162 seconds
#
#  (next mAP calculation at 100 iterations)
#  86: 0.738793, 2.222359 avg loss, 0.001000 rate, 25.712151 seconds, 5504 images, 6.108465 hours left
# Loaded: 0.000567 seconds
#
#  (next mAP calculation at 100 iterations)
#  87: 0.596361, 2.059760 avg loss, 0.001000 rate, 24.745292 seconds, 5568 images, 6.112661 hours left
# Loaded: 0.000270 seconds
#
#  (next mAP calculation at 100 iterations)
#  88: 1.015605, 1.955344 avg loss, 0.001000 rate, 25.921364 seconds, 5632 images, 6.114293 hours left
# Loaded: 0.000154 seconds
#
#  (next mAP calculation at 100 iterations)
#  89: 1.029170, 1.862727 avg loss, 0.001000 rate, 24.818755 seconds, 5696 images, 6.118818 hours left
# Loaded: 0.000424 seconds
#
#  (next mAP calculation at 100 iterations)
#  90: 0.806638, 1.757118 avg loss, 0.001000 rate, 25.242675 seconds, 5760 images, 6.120436 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
#  try to allocate additional workspace_size = 39.62 MB
#  CUDA allocate done!
# Loaded: 0.062105 seconds
#
#  (next mAP calculation at 100 iterations)
#  91: 0.812520, 1.662658 avg loss, 0.001000 rate, 6.022354 seconds, 5824 images, 6.123041 hours left
# Loaded: 0.000183 seconds
#
#  (next mAP calculation at 100 iterations)
#  92: 2.076656, 1.704058 avg loss, 0.001000 rate, 7.633639 seconds, 5888 images, 6.077174 hours left
# Loaded: 0.000453 seconds
#
#  (next mAP calculation at 100 iterations)
#  93: 0.770580, 1.610710 avg loss, 0.001000 rate, 9.719717 seconds, 5952 images, 6.035657 hours left
# Loaded: 0.000370 seconds
#
#  (next mAP calculation at 100 iterations)
#  94: 1.151214, 1.564760 avg loss, 0.001000 rate, 9.118270 seconds, 6016 images, 5.999790 hours left
# Loaded: 0.000124 seconds
#
#  (next mAP calculation at 100 iterations)
#  95: 0.822174, 1.490502 avg loss, 0.001000 rate, 7.536507 seconds, 6080 images, 5.962741 hours left
# Loaded: 0.000103 seconds
#
#  (next mAP calculation at 100 iterations)
#  96: 0.740586, 1.415510 avg loss, 0.001000 rate, 8.350522 seconds, 6144 images, 5.922060 hours left
# Loaded: 0.000584 seconds
#
#  (next mAP calculation at 100 iterations)
#  97: 1.346849, 1.408644 avg loss, 0.001000 rate, 8.783660 seconds, 6208 images, 5.883808 hours left
# Loaded: 0.000195 seconds
#
#  (next mAP calculation at 100 iterations)
#  98: 1.245099, 1.392290 avg loss, 0.001000 rate, 9.389919 seconds, 6272 images, 5.847004 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 100 iterations)
#  99: 1.034608, 1.356522 avg loss, 0.001000 rate, 8.688618 seconds, 6336 images, 5.812062 hours left
# Loaded: 0.000217 seconds
#
#  (next mAP calculation at 100 iterations)
#  100: 0.796006, 1.300470 avg loss, 0.001000 rate, 8.397054 seconds, 6400 images, 5.775687 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 79.48 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
#
#  detections_count = 580, unique_truth_count = 79
# class_id = 0, name = Ambulance, ap = 4.82%   	 (TP = 12, FP = 131)
#
#  for conf_thresh = 0.25, precision = 0.08, recall = 0.15, F1-score = 0.11
#  for conf_thresh = 0.25, TP = 12, FP = 131, FN = 67, average IoU = 4.93 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.048163, or 4.82 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.50) = 0.048163
# New best mAP!
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 101.06 MB
#  CUDA allocate done!
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  101: 0.994717, 1.269895 avg loss, 0.001000 rate, 26.551592 seconds, 6464 images, 5.758547 hours left
# Loaded: 0.000124 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  102: 0.859432, 1.228849 avg loss, 0.001000 rate, 26.932626 seconds, 6528 images, 5.767267 hours left
# Loaded: 0.000483 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  103: 0.748178, 1.180781 avg loss, 0.001000 rate, 24.748059 seconds, 6592 images, 5.776777 hours left
# Loaded: 0.000425 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  104: 1.308269, 1.193530 avg loss, 0.001000 rate, 24.724913 seconds, 6656 images, 5.780675 hours left
# Loaded: 0.000175 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  105: 0.568124, 1.130990 avg loss, 0.001000 rate, 23.986145 seconds, 6720 images, 5.784407 hours left
# Loaded: 0.000178 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  106: 0.692671, 1.087158 avg loss, 0.001000 rate, 26.058911 seconds, 6784 images, 5.786196 hours left
# Loaded: 0.000465 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  107: 0.973063, 1.075748 avg loss, 0.001000 rate, 24.236854 seconds, 6848 images, 5.793047 hours left
# Loaded: 0.000430 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  108: 0.968487, 1.065022 avg loss, 0.001000 rate, 24.763713 seconds, 6912 images, 5.795239 hours left
# Loaded: 0.000432 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  109: 0.900832, 1.048603 avg loss, 0.001000 rate, 25.718116 seconds, 6976 images, 5.798647 hours left
# Loaded: 0.000434 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  110: 0.725878, 1.016330 avg loss, 0.001000 rate, 25.564022 seconds, 7040 images, 5.804314 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 47.89 MB
#  CUDA allocate done!
# Loaded: 0.040465 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  111: 3.723707, 1.287068 avg loss, 0.001000 rate, 14.199487 seconds, 7104 images, 5.809472 hours left
# Loaded: 0.000210 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  112: 0.918118, 1.250173 avg loss, 0.001000 rate, 14.401685 seconds, 7168 images, 5.786542 hours left
# Loaded: 0.000553 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  113: 0.719770, 1.197133 avg loss, 0.001000 rate, 13.785980 seconds, 7232 images, 5.764201 hours left
# Loaded: 0.000557 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  114: 1.019044, 1.179324 avg loss, 0.001000 rate, 13.763488 seconds, 7296 images, 5.740528 hours left
# Loaded: 0.000102 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  115: 0.796632, 1.141055 avg loss, 0.001000 rate, 13.723387 seconds, 7360 images, 5.716998 hours left
# Loaded: 0.000575 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  116: 0.888830, 1.115832 avg loss, 0.001000 rate, 15.684495 seconds, 7424 images, 5.693565 hours left
# Loaded: 0.000399 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  117: 0.924382, 1.096687 avg loss, 0.001000 rate, 13.685011 seconds, 7488 images, 5.675145 hours left
# Loaded: 0.000533 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  118: 0.711961, 1.058215 avg loss, 0.001000 rate, 14.546652 seconds, 7552 images, 5.651961 hours left
# Loaded: 0.000150 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  119: 0.842436, 1.036637 avg loss, 0.001000 rate, 14.764334 seconds, 7616 images, 5.631083 hours left
# Loaded: 0.000158 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  120: 0.759036, 1.008877 avg loss, 0.001000 rate, 13.613000 seconds, 7680 images, 5.610904 hours left
# Resizing, random_coef = 1.40
#
#  448 x 448
#  try to allocate additional workspace_size = 91.42 MB
#  CUDA allocate done!
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  121: 0.739528, 0.981942 avg loss, 0.001000 rate, 16.736130 seconds, 7744 images, 5.588072 hours left
# Loaded: 0.000149 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  122: 0.777870, 0.961535 avg loss, 0.001000 rate, 17.225552 seconds, 7808 images, 5.573055 hours left
# Loaded: 0.000413 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  123: 0.657783, 0.931159 avg loss, 0.001000 rate, 17.084489 seconds, 7872 images, 5.559336 hours left
# Loaded: 0.000207 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.50 = 4.82 %, best = 4.82 %
#  124: 0.658657, 0.903909 avg loss, 0.001000 rate, 16.652167 seconds, 7936 images, 5.545364 hours left
# Loaded: 0.000040 seconds
# ^C

# %% [markdown]
# # <font style="color:white">Notes on Training</font>
# From the above training process we can make the following observations:
# 1. The images are resized after every 10 iterations
# It takes around 11 seconds per iteration which consists of 64 images for an image size of 576.
# 1. We can see that the training started very slowly in the first few iterations and then very gradually, the loss started reducing.
# 1. As we can see the learning rate increases gradually from 0 to 0.001 by the 100th batch ( burn_in was set to 100 ). It would stay there till the 1500th batch when it would again change to 0.0001.
# 1. mAP is calculated for every 100 iterations. It reaches >80% after 200 iterations.
# 1. You can check out the training graph for mAP v/s iterations which is saved in the file **chart.png**

# %% [markdown]
# ## <font style="color:white">Download our trained weights</font>
# You can download our weights which we trained using the link below.

# %%
# !wget "https://www.dropbox.com/s/qeno1qc1habd03d/yolov3-ambulance_last.weights?dl=1" -O backup/yolov3-ambulance-train_best.weights
# Out:
# --2022-04-18 11:17:13--  https://www.dropbox.com/s/qeno1qc1habd03d/yolov3-ambulance_last.weights?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/qeno1qc1habd03d/yolov3-ambulance_last.weights [following]
# --2022-04-18 11:17:14--  https://www.dropbox.com/s/dl/qeno1qc1habd03d/yolov3-ambulance_last.weights
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc97e6fde7fd1513b9d0b74563b.dl.dropboxusercontent.com/cd/0/get/BjrErVzjnR8Y_zqNgxQD9u34NdO8u4aXb_1EwWzaBGsW4QZSQd9djQ6m4gaPKdG2Zu-Vy2s8NCkcndWe9_XJrlDXkQd3H_034qEAdu99bmB7P4R-ko__bGucOsB94aDqFBcxF7QzErlNzL1RibhXoX-6qh86wxeJmI66VOE3VLiL4qp0o-LylpBtwBXUtJ9o70Y/file?dl=1# [following]
# --2022-04-18 11:17:14--  https://ucc97e6fde7fd1513b9d0b74563b.dl.dropboxusercontent.com/cd/0/get/BjrErVzjnR8Y_zqNgxQD9u34NdO8u4aXb_1EwWzaBGsW4QZSQd9djQ6m4gaPKdG2Zu-Vy2s8NCkcndWe9_XJrlDXkQd3H_034qEAdu99bmB7P4R-ko__bGucOsB94aDqFBcxF7QzErlNzL1RibhXoX-6qh86wxeJmI66VOE3VLiL4qp0o-LylpBtwBXUtJ9o70Y/file?dl=1
# Resolving ucc97e6fde7fd1513b9d0b74563b.dl.dropboxusercontent.com (ucc97e6fde7fd1513b9d0b74563b.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6017:15::a27d:20f
# Connecting to ucc97e6fde7fd1513b9d0b74563b.dl.dropboxusercontent.com (ucc97e6fde7fd1513b9d0b74563b.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246239852 (235M) [application/binary]
# Saving to: ‘backup/yolov3-ambulance-train_best.weights’
#
# backup/yolov3-ambul 100%[===================>] 234.83M  31.0MB/s    in 2m 58s
#
# 2022-04-18 11:20:14 (1.32 MB/s) - ‘backup/yolov3-ambulance-train_best.weights’ saved [246239852/246239852]

# %% [markdown]
# # <font style="color:white">9. Perform Inference</font>
# Finally, let us use the trained model to perform inference on some unseen images from the internet.

# %% [markdown]
# We have written a simple utility function which can be used to display the input and output similar to what we did in the previous section
#
# We are already familiar with the inference code which we saw in the previous section.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def display_output(imagePath):
    src = cv2.imread(imagePath,1)
    output = cv2.imread("predictions.jpg")

    plt.figure(figsize=[20,8])
    plt.subplot(121)
    plt.imshow(src[:,:,::-1])
    plt.title("Original Image")
    plt.subplot(122)
    plt.imshow(output[:,:,::-1])
    plt.title("Predictions")
    plt.show()

# %% [markdown]
# ### <font style="color:green">9.1. Test Image 1</font>

# %%
# !wget "https://www.dropbox.com/s/aad0pw7pf4ygs4b/traffic_1.jpg?dl=1" -O test1.jpg
# Out:
# --2022-04-18 11:15:18--  https://www.dropbox.com/s/aad0pw7pf4ygs4b/traffic_1.jpg?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/aad0pw7pf4ygs4b/traffic_1.jpg [following]
# --2022-04-18 11:15:18--  https://www.dropbox.com/s/dl/aad0pw7pf4ygs4b/traffic_1.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce9c502b75a08cc4c86f5f12318.dl.dropboxusercontent.com/cd/0/get/Bjp7twh6F75-EjV6RQlxJhnsSh97GodC9Avaz8HoHLG1GwocTC0p9UZpdhlSeRMezcT-he-ATnb4t3AsFe2aDfiUJJAz6ighkuyIRcmfjjBERCejNo_YIn0n1YQs6IHrERkuMBcyf316TFJVNTEWyCIpZ9UFnjQUtH6dXZPfkCnn2dfddtZlfvHlUrqeb46F4gw/file?dl=1# [following]
# --2022-04-18 11:15:19--  https://uce9c502b75a08cc4c86f5f12318.dl.dropboxusercontent.com/cd/0/get/Bjp7twh6F75-EjV6RQlxJhnsSh97GodC9Avaz8HoHLG1GwocTC0p9UZpdhlSeRMezcT-he-ATnb4t3AsFe2aDfiUJJAz6ighkuyIRcmfjjBERCejNo_YIn0n1YQs6IHrERkuMBcyf316TFJVNTEWyCIpZ9UFnjQUtH6dXZPfkCnn2dfddtZlfvHlUrqeb46F4gw/file?dl=1
# Resolving uce9c502b75a08cc4c86f5f12318.dl.dropboxusercontent.com (uce9c502b75a08cc4c86f5f12318.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6017:15::a27d:20f
# Connecting to uce9c502b75a08cc4c86f5f12318.dl.dropboxusercontent.com (uce9c502b75a08cc4c86f5f12318.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 179153 (175K) [application/binary]
# Saving to: ‘test1.jpg’
#
# test1.jpg           100%[===================>] 174.95K  1014KB/s    in 0.2s
#
# 2022-04-18 11:15:20 (1014 KB/s) - ‘test1.jpg’ saved [179153/179153]

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test1.jpg -thresh .6 2> /dev/null
display_output("test1.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
#
#  seen 64, trained: 32 K-images (0 Kilo-batches_64)
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# test1.jpg: Predicted in 26.070000 milli-seconds.
# Ambulance: 75%

# %% [markdown]
# We can see that the Ambulance from our previous example is now getting detected.
#
# Let us see some more examples!

# %% [markdown]
# ### <font style="color:green">9.2. Test Image 2</font>

# %%
# !wget https://d1muy2ct2wkbaz.cloudfront.net/video/259000/258637/580x325/0.jpg -O test2.jpg
# Out:
# --2022-04-18 11:16:25--  https://d1muy2ct2wkbaz.cloudfront.net/video/259000/258637/580x325/0.jpg
# Resolving d1muy2ct2wkbaz.cloudfront.net (d1muy2ct2wkbaz.cloudfront.net)... 65.8.165.128, 65.8.165.186, 65.8.165.99, ...
# Connecting to d1muy2ct2wkbaz.cloudfront.net (d1muy2ct2wkbaz.cloudfront.net)|65.8.165.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31241 (31K) [image/jpeg]
# Saving to: ‘test2.jpg’
#
# test2.jpg           100%[===================>]  30.51K  --.-KB/s    in 0.1s
#
# 2022-04-18 11:16:26 (300 KB/s) - ‘test2.jpg’ saved [31241/31241]

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test2.jpg -thresh .6  2> /dev/null
display_output("test2.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
#
#  seen 64, trained: 6 K-images (0 Kilo-batches_64)
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# test2.jpg: Predicted in 24.631000 milli-seconds.

# %% [markdown]
# ### <font style="color:green">9.3. Test Image 3</font>

# %%
# !wget https://www.straitstimes.com/sites/default/files/styles/article_pictrure_780x520_/public/articles/2020/01/18/ST_20200118_AMBULANCE_5390028.jpg -O test3.jpg
# Out:
# --2022-04-18 11:16:48--  https://www.straitstimes.com/sites/default/files/styles/article_pictrure_780x520_/public/articles/2020/01/18/ST_20200118_AMBULANCE_5390028.jpg
# Resolving www.straitstimes.com (www.straitstimes.com)... 152.195.55.6
# Connecting to www.straitstimes.com (www.straitstimes.com)|152.195.55.6|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://static1.straitstimes.com.sg/s3fs-public/styles/article_pictrure_780x520_/public/articles/2020/01/18/ST_20200118_AMBULANCE_5390028.jpg [following]
# --2022-04-18 11:16:48--  https://static1.straitstimes.com.sg/s3fs-public/styles/article_pictrure_780x520_/public/articles/2020/01/18/ST_20200118_AMBULANCE_5390028.jpg
# Resolving static1.straitstimes.com.sg (static1.straitstimes.com.sg)... 152.195.55.6
# Connecting to static1.straitstimes.com.sg (static1.straitstimes.com.sg)|152.195.55.6|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2022-04-18 11:16:49 ERROR 403: Forbidden.

# %%
# !./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test3.jpg -thresh .6  2> /dev/null
display_output("test3.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 32 K-images (0 Kilo-batches_64)
# test3.jpg: Predicted in 45.980000 milli-seconds.
# Ambulance: 99%
# Ambulance: 96%
# Ambulance: 99%

# %% [markdown]
# ### <font style="color:green">9.4. Test Image 4</font>

# %%
# !wget https://www.zhl.org.in/blog/wp-content/uploads/2019/09/Ambulance-Service.jpg -O test4.jpg
# Out:
# --2022-04-18 11:16:51--  https://www.zhl.org.in/blog/wp-content/uploads/2019/09/Ambulance-Service.jpg
# Resolving www.zhl.org.in (www.zhl.org.in)... 13.232.106.231
# Connecting to www.zhl.org.in (www.zhl.org.in)|13.232.106.231|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 294313 (287K) [image/jpeg]
# Saving to: ‘test4.jpg’
#
# test4.jpg           100%[===================>] 287.42K   187KB/s    in 1.5s
#
# 2022-04-18 11:16:54 (187 KB/s) - ‘test4.jpg’ saved [294313/294313]

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test4.jpg -thresh .6 2> /dev/null
display_output("test4.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
#
#  seen 64, trained: 6 K-images (0 Kilo-batches_64)
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# test4.jpg: Predicted in 20.295000 milli-seconds.

# %% [markdown]
# In the last example, we can see that there is a false positive - It classifies a Car as Ambulance. This is bound to happen since many ambulances are of the shape of a car.
