# %% [markdown]
# ## <font style="color:white">4.2. Prepare dataset files</font>
# We need to create a txt file which contains the path to the images. These files will be used while setting up the training.
#
# The data is split into train and test in the ratio of 80:20. So, we will use 80% of the data for training and the rest for testing after a few iterations of training.

# %%
import random
import os
import subprocess
import sys

image_dir = "./mask_no-mask_dataset"
f_val = open("data_test.txt", 'w')
f_train = open("data_train.txt", 'w')

path, dirs, files = next(os.walk(image_dir))
data_size = len(files)

ind = 0
data_test_size = int(0.2 * data_size)
test_array = random.sample(range(data_size), k=data_test_size)

for f in os.listdir(image_dir):
    if(f.split(".")[-1] == "jpg"):
        ind += 1
        
        if ind in test_array:
            f_val.write(image_dir+'/'+f+'\n')
        else:
            f_train.write(image_dir+'/'+f+'\n')

f_train.close()
f_val.close()

# %%
# download weights, they're too big
# !wget "https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1" -O darknet53.conv.74
# Out:
# --2022-04-18 09:18:39--  https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/18dwbfth7prbf0h/darknet53.conv.74 [following]
# --2022-04-18 09:18:39--  https://www.dropbox.com/s/dl/18dwbfth7prbf0h/darknet53.conv.74
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com/cd/0/get/BjrKDqk7PxYFq_GsZRlW0vNNfr8E5sftY37Sf2YAncq5rcD7nPVGgBXj8hOS_3aVDV_-ikomNzNNeRR_O0f7YOaUbGUeA7q1Tzgw9MZWrG9C5llVHDdLtS15spHKVEUNyqNO67ru1v-4Pbvv-hVHalYWBuusLqPrkiVnNMIDDZHhg4HZKFrRcDiFB2lpLBQAVU8/file?dl=1# [following]
# --2022-04-18 09:18:40--  https://uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com/cd/0/get/BjrKDqk7PxYFq_GsZRlW0vNNfr8E5sftY37Sf2YAncq5rcD7nPVGgBXj8hOS_3aVDV_-ikomNzNNeRR_O0f7YOaUbGUeA7q1Tzgw9MZWrG9C5llVHDdLtS15spHKVEUNyqNO67ru1v-4Pbvv-hVHalYWBuusLqPrkiVnNMIDDZHhg4HZKFrRcDiFB2lpLBQAVU8/file?dl=1
# Resolving uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com (uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6017:15::a27d:20f
# Connecting to uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com (uc83acba1a6c25400030a6219de4.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/binary]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  21.5MB/s    in 8.4s
#
# 2022-04-18 09:18:49 (18.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # <font style="color:white">7. Training Configuration</font>
# As explained in the theory section, we will use the config file to specify the various training parameters. A gist of all the parameters is given below:
#
# ## <font style="color:white">7.1. Data Setup</font>
# In the file **`yolov3-ambulance-setup.data`**(included in our code), we need to provide information about the specifications for our object detector and some relevant paths.
#
# The contents of the file are as follows:
# ```
# classes = 1
# train  = data_train.txt
# valid  = data_test.txt
# names = class.names
# backup = backup/
# ```
# The classes parameter needs the number of classes. In our case, it is 1.
#
# You need to provide the absolute paths of the files **`data_train.txt`** and **`data_test.txt`** generated earlier, which have the list of files to be used for training(train parameter) and validation(valid parameter) respectively.
#
# The names field represents the path of a file which contains the names of all the classes. We have included the **`class.names`** file which contains the class name **`Ambulance`**. You will need to provide its absolute path in your machine here.
#
# Lastly, for the **`backup`** parameter, we need to give the path to an existing directory where we can store the intermediate weights files as the training progresses.
#
# ## <font style="color:white">7.2. Training Config File</font>
# Along with the yolov3-ambulance-setup.data and class.names files, YOLOv3 also needs a configuration file **`yolov3-ambulance-train.cfg`**. It is based on the demo configuration file, yolov3-voc.cfg (comes with darknet code), which was used to train on the VOC dataset. All the important training parameters are stored in this configuration file. Let us understand what they mean and what values to set them to.
#
# ### <font style="color:green">7.2.1 Batch hyper-parameter in YOLOv3</font>
# Let’s learn more about batch and subdivision parameter.
# ```
# [net]
# # Testing
# # batch=1
# # subdivisions=1
# # Training
# batch=64
# subdivisions=16
# ```
# The batch parameter indicates the batch size used during training.
#
# Our training set contains a few hundred images, but it is not uncommon to train on million of images. The training process involves iteratively updating the weights of the neural network based on how many mistakes it is making on the training dataset.
#
# It is impractical (and unnecessary) to use all images in the training set at once to update the weights. So, a small subset of images is used in one iteration, and this subset is called the batch size.
#
# When the batch size is set to 64, it means 64 images are used in one iteration to update the parameters of the neural network.
#
# ### <font style="color:green">7.2.2 Subdivisions configuration parameter in YOLOv3</font>
# Even though you may want to use a batch size of 64 for training your neural network, you may not have a GPU with enough memory to use a batch size of 64. Fortunately, Darknet allows you to specify a variable called subdivisions that lets you process a fraction of the batch size at one time on your GPU.
#
# You can start the training with subdivisions=1, and if you get an Out of memory error, increase the subdivisions parameter by multiples of 2(e.g. 2, 4, 8, 16) till the training proceeds successfully. The GPU will process batch/subdivision number of images at any time, but the full batch or iteration would be complete only after all the 64 (as set above) images are processed.
#
# During testing, both batch and subdivision are set to 1.
#
# ### <font style="color:green">7.2.3 Width, Height, Channels</font>
# These configuration parameters specify the input image size and the number of channels.
#
# ```
# width=416
# height=416
# channels=3
# ```
# The input training images are first resized to width x height before training. Here we use the default values of 416×416. The results might improve if we increase it to 608×608, but it would take longer to train too. channels=3 indicates that we would be processing 3-channel RGB input images.
#
# ### <font style="color:green">7.2.4 Momentum and Decay</font>
# The configuration file contains a few parameters that control how the weight is updated.
# ```
# momentum=0.9
# decay=0.0005
# ```
# In the previous section, we mentioned how the weights of a neural network are updated based on a small batch of images and not the entire dataset. Because of this reason, the weight updates fluctuate quite a bit. That is why a parameter momentum is used to penalize large weight changes between iterations.
#
# A typical neural network has millions of weights and therefore they can easily overfit any training data. Overfitting simply means it will do very well on training data and poorly on test data. It is almost like the neural network has memorized the answer to all images in the training set, but really not learned the underlying concept. One of the ways to mitigate this problem is to penalize large value for weights. The parameter decay controls this penalty term. The default value works just fine, but you may want to tweak this if you notice overfitting.
#
# ### <font style="color:green">7.2.5 Learning Rate, Steps, Scales, Burn In (warm-up)</font>
# ```
# learning_rate=0.001
# policy=steps
# steps=800
# scales=.1
# burn_in=100
# ```
# The parameter learning rate controls how aggressively we should learn based on the current batch of data. Typically this is a number between 0.01 and 0.0001.
#
# At the beginning of the training process, we are starting with zero information and so the learning rate needs to be high. But as the neural network sees a lot of data, the weights need to change less aggressively. In other words, the learning rate needs to be decreased over time. In the configuration file, this decrease in learning rate is accomplished by first specifying that our learning rate decreasing policy is steps. In the above example, the learning rate will start from 0.001 and remain constant for 800 iterations, and then it will multiply by scales to get the new learning rate. We could have also specified multiple steps and scales.
#
# In the previous paragraph, we mentioned that the learning rate needs to be high in the beginning and low later on. While that statement is largely true, it has been empirically found that the training speed tends to increase if we have a lower learning rate for a short period of time at the very beginning. This is controlled by the burn_in parameter. Sometimes this **`burn-in`** period is also called warm-up period.
#
# ### <font style="color:green">7.2.6 Data augmentation</font>
# We know data collection takes a long time and it is difficult to find high quality annotated data. We want to make maximum use of this data by cooking up new data. This process is called data augmentation. For example, an image of the ambulance rotated by 5 degrees is still an image of a ambulance. The angle parameter in the configuration file allows you to randomly rotate the given image by ± angle.
#
# Similarly, if we transform the colors of the entire picture using saturation, exposure, and hue, it is still a picture of the ambulance.
# ```
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# ```
# We used the default values for training.
#
# ### <font style="color:green">7.2.7 Number of iterations</font>
# Finally, we need to specify how many iterations should the training process be run for.
# ```
# max_batches=1000
# ```
#
# For multi-class object detectors, the max_batches number is higher, i.e. we need to run for more number of batches(e.g. in yolov3-voc.cfg). For an n-classes object detector, it is advisable to run the training for at least 2000*n batches. In our case with only 1 class, 1000 seemed like a safe number for max_batches.
#
# You should try to change the parameter and see how it performs.
#
# ### <font style="color:green">7.2.8 Change filters parameter in conv layers [Important for multiple objects]</font>
# Change the filters parameter in the convolutional layer just before the yolo layer according to the formula
#
# **`filters=( classes + 5 ) * 3`**
#
# Since we are using classes = 1, thus, #filters in our case is 18. You should make this change if you are dealing with more classes.
#
#
# ## <font color="white">7.3. Names file </font>
# We need to specify the names of the classes in the **`.names`** file. In our case, there is only 1 class and thus, only Ambulance is added to that file.

# %% [markdown]
# # <font style="color:white">8. Start Training </font>
# For starting training using darknet, we need to execute the following command. Here we are specifying the
# 1. path to the setup file,
# 1. path to config file,
# 1. path to convolutional weights file
#
# and also passing some flags such as:
#
# - **`dont_show`** which wont display the graphs. This is required for Colab since it does not have a display and it will crash if it tries to display, not if you run the notebook on your local system.
# - **`map`** - this will calculate mAP - mean average precision for the test data which we have specified using the data_test.txt file which contains 20% of our data.

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector train yolov3-mask-setup.data yolov3-mask-train.cfg ./backup/yolov3-mask-train_last.weights -map 2> train_log.txt

# note that the images are not complete since training was resumed multiple times
# Out:
#  Prepare additional network for mAP calculation...
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# yolov3-mask-train
# net.optimized_memory = 0
# mini_batch = 2, batch = 64, time_steps = 1, train = 1
#
#  seen 64, trained: 211 K-images (3 Kilo-batches_64)
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
#  If error occurs - run training with flag: -dont_show
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 164.41 MB
#  CUDA allocate done!
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3301: 0.779075, 0.779075 avg loss, 0.001000 rate, 34.950330 seconds, 211264 images, -1.000000 hours left
# Loaded: 0.000074 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3302: 0.445644, 0.745732 avg loss, 0.001000 rate, 34.684970 seconds, 211328 images, 16.494640 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3303: 0.638310, 0.734990 avg loss, 0.001000 rate, 33.794450 seconds, 211392 images, 16.493292 hours left
# Loaded: 0.000084 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3304: 0.672197, 0.728710 avg loss, 0.001000 rate, 33.839765 seconds, 211456 images, 16.487662 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3305: 0.914856, 0.747325 avg loss, 0.001000 rate, 34.136519 seconds, 211520 images, 16.482209 hours left
# Loaded: 0.000096 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3306: 0.852957, 0.757888 avg loss, 0.001000 rate, 34.070663 seconds, 211584 images, 16.478113 hours left
# Loaded: 0.000034 seconds
#
#  (next mAP calculation at 3400 iterations)
#  
hours left
# Loaded: 0.000084 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3386: 0.886215, 0.915171 avg loss, 0.001000 rate, 26.472695 seconds, 216704 images, 11.609294 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3387: 0.729079, 0.896561 avg loss, 0.001000 rate, 27.211266 seconds, 216768 images, 11.611888 hours left
# Loaded: 0.000104 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3388: 0.840991, 0.891004 avg loss, 0.001000 rate, 25.681066 seconds, 216832 images, 11.617691 hours left
# Loaded: 0.000067 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3389: 0.745044, 0.876408 avg loss, 0.001000 rate, 25.773688 seconds, 216896 images, 11.616508 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3390: 0.847547, 0.873522 avg loss, 0.001000 rate, 30.332607 seconds, 216960 images, 11.615681 hours left
# Resizing, random_coef = 1.40
#
#  576 x 576
#  try to allocate additional workspace_size = 127.83 MB
#  CUDA allocate done!
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3391: 1.112940, 0.897464 avg loss, 0.001000 rate, 28.448802 seconds, 217024 images, 11.635178 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3392: 0.859284, 0.893646 avg loss, 0.001000 rate, 29.118272 seconds, 217088 images, 11.645977 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3393: 0.685387, 0.872820 avg loss, 0.001000 rate, 25.754186 seconds, 217152 images, 11.659579 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3394: 1.099639, 0.895502 avg loss, 0.001000 rate, 27.359013 seconds, 217216 images, 11.657947 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3395: 1.065503, 0.912502 avg loss, 0.001000 rate, 27.976909 seconds, 217280 images, 11.663420 hours left
# Loaded: 0.000111 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3396: 1.257442, 0.946996 avg loss, 0.001000 rate, 28.055434 seconds, 217344 images, 11.671516 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3397: 0.564532, 0.908750 avg loss, 0.001000 rate, 29.333084 seconds, 217408 images, 11.679804 hours left
# Loaded: 0.000084 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3398: 0.681260, 0.886001 avg loss, 0.001000 rate, 24.877206 seconds, 217472 images, 11.693620 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 3400 iterations)
#  3399: 1.051760, 0.902577 avg loss, 0.001000 rate, 24.791130 seconds, 217536 images, 11.687388 hours left
# Loaded: 0.000067 seconds
# ^C

# %% [markdown]
# # <font style="color:white">Notes on Training</font>
# From the above training process we can make the following observations:
# 1. The images are resized after every 10 iterations
# It takes around 11 seconds per iteration which consists of 64 images for an image size of 576.
# 1. We can see that the training started very slowly in the first few iterations and then very gradually, the loss started reducing.
# 1. As we can see the learning rate increases gradually from 0 to 0.001 by the 100th batch ( burn_in was set to 100 ). It would stay there till the 1500th batch when it would again change to 0.0001.
# 1. mAP is calculated for every 100 iterations. It reaches >80% after 200 iterations.
# 1. You can check out the training graph for mAP v/s iterations which is saved in the file **chart.png**

# %% [markdown]
# # <font style="color:white">9. Perform Inference</font>
# Finally, let us use the trained model to perform inference on some unseen images from the internet.

# %% [markdown]
# We have written a simple utility function which can be used to display the input and output similar to what we did in the previous section
#
# We are already familiar with the inference code which we saw in the previous section.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def display_output(imagePath):
    src = cv2.imread(imagePath,1)
    output = cv2.imread("predictions.jpg")

    plt.figure(figsize=[20,8])
    plt.subplot(121)
    plt.imshow(src[:,:,::-1])
    plt.title("Original Image")
    plt.subplot(122)
    plt.imshow(output[:,:,::-1])
    plt.title("Predictions")
    plt.show()

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights /home/jeff/Documents/Code/YOLO-Mask-Detector/yolo_test/test-image1.jpg -thresh .6 2> /dev/null
display_output("yolo_test/test-image1.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
#
#  seen 64, trained: 211 K-images (3 Kilo-batches_64)
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# /home/jeff/Documents/Code/YOLO-Mask-Detector/yolo_test/test-image1.jpg: Predicted in 79.096000 milli-seconds.
# Mask: 100%

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights /home/jeff/Documents/Code/YOLO-Mask-Detector/yolo_test/test-image2.jpg -thresh .6 2> /dev/null
display_output("yolo_test/test-image2.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
#
#  seen 64, trained: 211 K-images (3 Kilo-batches_64)
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# /home/jeff/Documents/Code/YOLO-Mask-Detector/yolo_test/test-image2.jpg: Predicted in 77.896000 milli-seconds.
# Mask: 100%
# Mask: 99%
# Mask: 88%
# No Mask: 100%
# Mask: 99%

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights /home/jeff/Documents/Code/YOLO-Mask-Detector/yolo_test/test-image3.jpg -thresh .6 2> /dev/null
display_output("yolo_test/test-image3.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
#
#  seen 64, trained: 211 K-images (3 Kilo-batches_64)
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# /home/jeff/Documents/Code/YOLO-Mask-Detector/yolo_test/test-image3.jpg: Predicted in 82.922000 milli-seconds.
# Mask: 80%
# Mask: 100%
# Mask: 100%
# No Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
# Mask: 100%
# Mask: 100%

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights /home/jeff/Documents/Code/YOLO-Mask-Detector/yolo_test/test-image4.jpg -thresh .6 2> /dev/null
display_output("yolo_test/test-image4.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
#
#  seen 64, trained: 211 K-images (3 Kilo-batches_64)
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# /home/jeff/Documents/Code/YOLO-Mask-Detector/yolo_test/test-image4.jpg: Predicted in 88.877000 milli-seconds.
# No Mask: 98%
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# No Mask: 99%
# Mask: 100%
# Mask: 65%
# Mask: 100%

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector demo yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights yolo_test/test-video1.mp4 -thresh .6 -out_filename yolo_test/test-video1_detected.avi -dont_show
# Out:
#  CUDA-version: 11020 (11060), cuDNN: 8.1.1, GPU count: 1
#  OpenCV version: 4.5.3
# Demo
#  0 : compute_capability = 860, cudnn_half = 0, GPU: NVIDIA GeForce RTX 3060 Laptop GPU
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     21       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  21 0.007 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     21       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  21 0.015 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 4x    26 x  26 x 128 ->  104 x 104 x 128
#   98 route  97 11 	                           ->  104 x 104 x 256
#   99 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  100 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  101 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  102 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  103 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  104 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  105 conv     21       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x  21 0.116 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 81.259
# avg_outputs = 633320
#  Allocate additional workspace_size = 22.23 MB
# Loading weights from backup/yolov3-mask-train_best.weights...
#  seen 64, trained: 211 K-images (3 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# video file: yolo_test/test-video1.mp4
# Video stream: 1600 x 842
# Objects:
#
#
# FPS:0.0 	 AVG_FPS:0.0
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:1.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:1.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:2.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:3.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:3.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:4.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:4.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:4.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:5.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:5.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:5.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:6.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:6.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:6.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:7.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:7.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:7.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:8.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:8.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:8.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:8.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:8.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:8.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
#
# FPS:9.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:9.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:9.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
#
# FPS:9.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
# No Mask: 98%
# Mask: 88%
#
# FPS:9.7 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
# No Mask: 98%
# Mask: 87%
#
# FPS:9.8 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 99%
# No Mask: 88%
# Mask: 99%
#
# FPS:9.8 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 100%
# No Mask: 98%
# Mask: 100%
#
# FPS:10.1 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 98%
# No Mask: 93%
# Mask: 100%
# Mask: 61%
#
# FPS:10.2 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 99%
#
# FPS:10.4 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
#
# FPS:10.7 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
#
# FPS:10.8 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
#
# FPS:10.9 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
#
# FPS:10.9 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
#
# FPS:11.2 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
#
# FPS:11.4 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 98%
# Mask: 100%
# Mask: 100%
#
# FPS:11.5 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# No Mask: 79%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:11.7 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 98%
# Mask: 84%
#
# FPS:11.7 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 90%
#
# FPS:11.8 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
# Mask: 90%
#
# FPS:11.9 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 89%
#
# FPS:12.0 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 89%
#
# FPS:12.2 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 88%
#
# FPS:12.1 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.2 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.2 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 90%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.1 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.0 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.9 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:11.7 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:11.4 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:11.3 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 87%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:11.2 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 87%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:11.1 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 87%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:11.1 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 86%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:11.4 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:11.5 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.6 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.7 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 90%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 92%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:11.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:10.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:10.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:11.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 87%
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 87%
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 79%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 76%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 79%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 79%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 80%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 77%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 77%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 98%
# Mask: 80%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 96%
# Mask: 86%
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
# Mask: 86%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 83%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 83%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 84%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 86%
#
# FPS:12.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.1 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 84%
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.9 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 84%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:12.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 90%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 90%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.7 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.6 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.6 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
# Mask: 94%
#
# FPS:11.7 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 96%
# Mask: 93%
#
# FPS:11.6 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 96%
# Mask: 93%
#
# FPS:11.6 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 85%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
# Mask: 68%
#
# FPS:11.6 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:11.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.5 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.1 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:13.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:13.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.7 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.8 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.7 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.8 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.5 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 92%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.4 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 90%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.5 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.7 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.8 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.7 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 90%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.8 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.7 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.7 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.5 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.7 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.4 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.3 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.2 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.2 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.1 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.2 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.4 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.3 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.4 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:12.5 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.4 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.5 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.5 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.5 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.4 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 77%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 84%
#
# FPS:12.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.1 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:11.6 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:11.4 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:11.2 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:11.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:11.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:11.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:11.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:11.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
# Mask: 84%
#
# FPS:10.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
# Mask: 84%
#
# FPS:10.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 89%
#
# FPS:10.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:10.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:10.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:10.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:10.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:10.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:10.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:10.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 86%
#
# FPS:10.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:10.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:10.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:10.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:10.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:10.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 83%
#
# FPS:10.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 82%
#
# FPS:10.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:10.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 84%
#
# FPS:10.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:10.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:10.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 79%
#
# FPS:10.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 72%
#
# FPS:10.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# ...
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.5 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 84%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 79%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:12.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:12.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 92%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 90%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.8 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 89%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:12.8 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.8 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.8 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:12.3 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 77%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.2 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 77%
#
# FPS:12.3 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 77%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 77%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 84%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 79%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:12.3 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 84%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 79%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 80%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.5 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.4 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 88%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 84%
#
# FPS:12.8 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 83%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 82%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 87%
#
# FPS:12.8 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:12.8 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:12.8 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 90%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 89%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:12.7 	 AVG_FPS:12.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 86%
# Mask: 100% Stream closed.
#
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 97%
#
# FPS:12.6 	 AVG_FPS:12.4
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.

# %%
# !/home/jeff/Documents/Code/darknet/darknet detector demo yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights yolo_test/test-video2.mp4 -thresh .6 -out_filename yolo_test/test-video2_detected.avi -dont_show
# Out:
#  CUDA-version: 11020 (11060), cuDNN: 8.1.1, GPU count: 1
#  OpenCV version: 4.5.3
# Demo
#  0 : compute_capability = 860, cudnn_half = 0, GPU: NVIDIA GeForce RTX 3060 Laptop GPU
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     21       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  21 0.007 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     21       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  21 0.015 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 4x    26 x  26 x 128 ->  104 x 104 x 128
#   98 route  97 11 	                           ->  104 x 104 x 256
#   99 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  100 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  101 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  102 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  103 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  104 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  105 conv     21       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x  21 0.116 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 81.259
# avg_outputs = 633320
#  Allocate additional workspace_size = 22.23 MB
# Loading weights from backup/yolov3-mask-train_best.weights...
#  seen 64, trained: 211 K-images (3 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# video file: yolo_test/test-video2.mp4
# Video stream: 1280 x 718
# Objects:
#
#
# FPS:0.0 	 AVG_FPS:0.0
# Objects:
#
# No Mask: 93%
# No Mask: 82%
#
# FPS:1.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 67%
#
# FPS:2.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 84%
# No Mask: 70%
# No Mask: 64%
#
# FPS:3.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 86%
# No Mask: 77%
# No Mask: 71%
#
# FPS:4.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 89%
#
# FPS:5.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# No Mask: 60%
#
# FPS:6.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 61%
#
# FPS:7.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 63%
# Mask: 72%
#
# FPS:8.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 82%
# Mask: 78%
#
# FPS:8.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# No Mask: 81%
# Mask: 91%
#
# FPS:8.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 81%
# No Mask: 66%
# Mask: 80%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 82%
# No Mask: 68%
# Mask: 82%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# No Mask: 83%
# No Mask: 78%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# No Mask: 88%
# Mask: 69%
#
# FPS:9.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# No Mask: 81%
# No Mask: 70%
# No Mask: 61%
#
# FPS:9.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 82%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 82%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 92%
# No Mask: 79%
#
# FPS:9.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# No Mask: 75%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 71%
# Mask: 73%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 69%
# Mask: 70%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 61%
# Mask: 70%
#
# FPS:9.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
#
# FPS:9.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
#
# FPS:9.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 97%
#
# FPS:9.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 79%
# Mask: 100%
#
# FPS:9.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 81%
# Mask: 98%
#
# FPS:9.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 99%
#
# FPS:10.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 93%
# Mask: 99%
#
# FPS:9.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 93%
# Mask: 99%
#
# FPS:9.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 65%
# Mask: 99%
#
# FPS:10.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 63%
# Mask: 92%
#
# FPS:10.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
#
# FPS:10.0 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
#
# FPS:10.0 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
#
# FPS:9.8 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
#
# FPS:9.7 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 62%
#
# FPS:9.7 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 61%
#
# FPS:9.8 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 64%
#
# FPS:9.9 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
#
# FPS:9.8 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 69%
#
# FPS:9.8 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 63%
#
# FPS:9.6 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
#
# FPS:9.6 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 72%
#
# FPS:9.6 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 90%
# No Mask: 89%
#
# FPS:9.7 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 76%
# No Mask: 64%
#
# FPS:9.6 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# No Mask: 92%
#
# FPS:9.7 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 92%
#
# FPS:9.6 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 92%
#
# FPS:9.7 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 86%
#
# FPS:9.9 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 82%
#
# FPS:10.3 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 87%
#
# FPS:10.4 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 94%
# No Mask: 65%
#
# FPS:10.7 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 95%
# No Mask: 65%
#
# FPS:10.8 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 90%
# No Mask: 89%
#
# FPS:11.0 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 79%
# No Mask: 74%
#
# FPS:11.3 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 79%
#
# FPS:11.4 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 71%
# No Mask: 65%
#
# FPS:11.6 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 83%
# No Mask: 81%
#
# FPS:11.7 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 83%
# No Mask: 81%
#
# FPS:11.9 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 94%
#
# FPS:12.0 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
#
# FPS:11.7 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
#
# FPS:11.5 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 94%
#
# FPS:11.3 	 AVG_FPS:10.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 90%
#
# FPS:11.1 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 90%
#
# FPS:11.0 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 95%
#
# FPS:10.8 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 98%
#
# FPS:10.6 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 94%
#
# FPS:10.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 85%
#
# FPS:10.4 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 97%
#
# FPS:10.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 97%
#
# FPS:10.7 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 94%
#
# FPS:10.9 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 95%
#
# FPS:11.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 91%
#
# FPS:11.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 91%
#
# FPS:11.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 93%
#
# FPS:11.4 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 93%
#
# FPS:11.7 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 83%
#
# FPS:11.7 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 88%
#
# FPS:11.7 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 93%
#
# FPS:11.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 91%
#
# FPS:11.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 65%
#
# FPS:11.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 71%
#
# FPS:11.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 91%
#
# FPS:11.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 88%
# No Mask: 80%
#
# FPS:11.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 92%
#
# FPS:11.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 87%
#
# FPS:11.6 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 82%
#
# FPS:11.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 82%
#
# FPS:11.8 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# No Mask: 80%
#
# FPS:11.8 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# No Mask: 94%
#
# FPS:12.1 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 99%
# No Mask: 91%
#
# FPS:12.1 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 94%
#
# FPS:12.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 89%
# No Mask: 66%
#
# FPS:12.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 89%
# No Mask: 61%
#
# FPS:12.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 70%
# Mask: 67%
#
# FPS:12.1 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 91%
#
# FPS:12.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 88%
#
# FPS:12.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 70%
#
# FPS:12.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 81%
# No Mask: 72%
#
# FPS:12.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 82%
# No Mask: 72%
#
# FPS:12.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 71%
# Mask: 62%
#
# FPS:12.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 86%
#
# FPS:12.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 78%
# Mask: 80%
#
# FPS:12.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 90%
# No Mask: 68%
# Mask: 96%
# Mask: 85%
#
# FPS:12.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 92%
# Mask: 96%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 92%
# Mask: 97%
#
# FPS:11.9 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 92%
# Mask: 73%
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# No Mask: 79%
# No Mask: 64%
# Mask: 94%
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 85%
# Mask: 82%
#
# FPS:11.1 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 81%
# No Mask: 60%
#
# FPS:11.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 63%
# Mask: 92%
#
# FPS:11.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 61%
# Mask: 92%
#
# FPS:10.9 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 85%
#
# FPS:10.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 92%
#
# FPS:10.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
#
# FPS:10.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:10.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 72%
#
# FPS:10.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 62%
# Mask: 72%
#
# FPS:10.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 79%
#
# FPS:10.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 95%
# Mask: 95%
#
# FPS:10.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 89%
#
# FPS:10.1 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 87%
#
# FPS:10.1 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 93%
# Mask: 90%
#
# FPS:10.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 93%
# Mask: 91%
#
# FPS:9.9 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 71%
# Mask: 95%
#
# FPS:9.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 83%
# No Mask: 68%
# Mask: 92%
# Mask: 71%
#
# FPS:9.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 64%
# Mask: 97%
# Mask: 96%
#
# FPS:9.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 65%
# Mask: 99%
# Mask: 99%
#
# FPS:9.8 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 98%
#
# FPS:9.8 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 98%
#
# FPS:9.8 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 98%
# Mask: 76%
#
# FPS:9.8 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# No Mask: 79%
# Mask: 99%
# Mask: 95%
# Mask: 85%
#
# FPS:9.8 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 77%
# No Mask: 71%
# Mask: 98%
# Mask: 89%
# Mask: 84%
#
# FPS:9.8 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 92%
# No Mask: 91%
# Mask: 99%
# Mask: 95%
# Mask: 71%
#
# FPS:9.9 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 88%
# Mask: 84%
# Mask: 82%
#
# FPS:9.9 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 65%
# Mask: 100%
# Mask: 88%
# Mask: 83%
# Mask: 82%
#
# FPS:9.9 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 90%
# No Mask: 82%
# No Mask: 81%
# Mask: 98%
# Mask: 91%
# Mask: 65%
# Mask: 64%
#
# FPS:10.0 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 74%
# No Mask: 62%
# Mask: 99%
# Mask: 97%
# Mask: 92%
#
# FPS:10.0 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# No Mask: 85%
# No Mask: 77%
# Mask: 100%
# Mask: 96%
# Mask: 74%
# Mask: 63%
#
# FPS:10.0 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 82%
# No Mask: 76%
# Mask: 100%
# Mask: 98%
# Mask: 67%
#
# FPS:10.0 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 86%
# No Mask: 78%
# No Mask: 67%
# Mask: 100%
# Mask: 99%
#
# FPS:9.9 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 84%
# No Mask: 78%
# No Mask: 66%
# Mask: 100%
# Mask: 99%
#
# FPS:9.9 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 78%
# No Mask: 76%
# Mask: 100%
# Mask: 98%
#
# FPS:9.9 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 82%
# Mask: 100%
# Mask: 99%
#
# FPS:9.9 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 79%
# No Mask: 74%
# No Mask: 68%
# Mask: 100%
# Mask: 100%
#
# FPS:9.9 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# No Mask: 87%
# Mask: 100%
# Mask: 99%
#
# FPS:9.8 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 74%
# Mask: 100%
# Mask: 100%
#
# FPS:9.7 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 71%
# Mask: 100%
# Mask: 99%
#
# FPS:9.7 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 74%
# No Mask: 66%
# Mask: 100%
# Mask: 100%
#
# FPS:9.7 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 86%
# Mask: 100%
# Mask: 100%
#
# FPS:9.6 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 77%
# Mask: 100%
# Mask: 99%
#
# FPS:9.6 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 74%
# Mask: 99%
# Mask: 96%
#
# FPS:9.6 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 67%
# Mask: 99%
#
# FPS:9.6 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 66%
# Mask: 99%
#
# FPS:9.6 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:9.6 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:9.7 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 76%
# Mask: 100%
#
# FPS:9.8 	 AVG_FPS:10.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 66%
# Mask: 100%
#
# FPS:10.0 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 84%
# Mask: 100%
#
# FPS:10.0 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 82%
# Mask: 100%
#
# FPS:10.0 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# Mask: 98%
#
# FPS:10.1 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 98%
#
# FPS:10.4 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 87%
# Mask: 100%
#
# FPS:10.6 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 92%
# Mask: 99%
#
# FPS:10.9 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 89%
# No Mask: 68%
# Mask: 100%
#
# FPS:11.1 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 89%
# No Mask: 76%
# Mask: 100%
#
# FPS:11.3 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 92%
# Mask: 100%
#
# FPS:11.4 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 89%
# No Mask: 84%
# Mask: 100%
#
# FPS:11.5 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# No Mask: 85%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 86%
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 84%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 82%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 93%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 87%
# No Mask: 85%
# No Mask: 71%
# Mask: 100%
#
# FPS:11.4 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 96%
# No Mask: 90%
# Mask: 100%
#
# FPS:11.2 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 97%
# No Mask: 74%
# No Mask: 71%
# Mask: 100%
#
# FPS:10.9 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 99%
# No Mask: 92%
# No Mask: 88%
# No Mask: 75%
# Mask: 98%
#
# FPS:10.6 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 99%
# No Mask: 92%
# No Mask: 88%
# No Mask: 75%
# Mask: 98%
#
# FPS:10.3 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 87%
# No Mask: 87%
# No Mask: 79%
# No Mask: 65%
# Mask: 80%
#
# FPS:10.4 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 89%
# No Mask: 83%
# No Mask: 72%
#
# FPS:10.5 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 81%
# No Mask: 78%
#
# FPS:10.6 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# No Mask: 80%
#
# FPS:10.8 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 79%
# No Mask: 76%
#
# FPS:10.8 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 78%
# No Mask: 75%
#
# FPS:10.6 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 96%
# No Mask: 88%
# No Mask: 85%
#
# FPS:10.4 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 90%
# No Mask: 82%
# No Mask: 79%
#
# FPS:10.3 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# No Mask: 88%
# No Mask: 72%
#
# FPS:10.2 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# No Mask: 72%
#
# FPS:10.1 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 82%
# No Mask: 81%
#
# FPS:9.9 	 AVG_FPS:9.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 83%
# No Mask: 80%
# No Mask: 60%
#
# FPS:10.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 93%
# No Mask: 88%
#
# FPS:10.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 90%
# No Mask: 78%
# No Mask: 66%
#
# FPS:10.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 94%
# No Mask: 91%
# No Mask: 82%
#
# FPS:10.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# No Mask: 93%
# No Mask: 90%
#
# FPS:10.4 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 95%
# No Mask: 95%
# No Mask: 76%
#
# FPS:10.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# No Mask: 95%
# No Mask: 78%
#
# FPS:10.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 97%
# No Mask: 96%
# No Mask: 92%
#
# FPS:10.0 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 88%
# No Mask: 87%
# No Mask: 75%
#
# FPS:9.9 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 95%
# No Mask: 83%
# No Mask: 65%
#
# FPS:9.8 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 98%
#
# FPS:9.7 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 97%
# No Mask: 75%
#
# FPS:9.9 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 96%
# No Mask: 80%
#
# FPS:10.2 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# No Mask: 76%
#
# FPS:10.1 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 74%
#
# FPS:10.0 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 95%
# No Mask: 70%
#
# FPS:10.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# No Mask: 94%
# No Mask: 75%
# Mask: 99%
#
# FPS:10.6 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 86%
# Mask: 100%
# Mask: 87%
#
# FPS:10.7 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 88%
# Mask: 100%
# Mask: 87%
#
# FPS:10.9 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 95%
# No Mask: 91%
# Mask: 100%
# Mask: 84%
#
# FPS:11.1 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 92%
# No Mask: 65%
# Mask: 99%
#
# FPS:10.9 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 76%
# Mask: 100%
# Mask: 66%
#
# FPS:10.8 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 92%
# No Mask: 75%
# Mask: 100%
# Mask: 74%
#
# FPS:10.9 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 96%
# No Mask: 80%
# Mask: 100%
#
# FPS:10.9 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 96%
# No Mask: 79%
# Mask: 100%
#
# FPS:11.0 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 93%
# No Mask: 78%
# Mask: 100%
#
# FPS:11.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 90%
# Mask: 100%
#
# FPS:11.3 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 72%
# Mask: 100%
#
# FPS:11.4 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 82%
# No Mask: 72%
# Mask: 98%
#
# FPS:11.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# No Mask: 85%
# No Mask: 82%
#
# FPS:11.5 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# No Mask: 83%
# No Mask: 79%
#
# FPS:11.7 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 96%
# No Mask: 89%
# No Mask: 74%
#
# FPS:11.7 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 94%
# No Mask: 93%
# No Mask: 87%
# No Mask: 78%
#
# FPS:11.9 	 AVG_FPS:10.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 95%
# No Mask: 89%
# No Mask: 86%
# No Mask: 60%
#
# FPS:12.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 96%
# No Mask: 91%
#
# FPS:12.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 98%
# No Mask: 95%
# No Mask: 84%
#
# FPS:11.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 98%
# No Mask: 95%
# No Mask: 82%
#
# FPS:11.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 98%
# No Mask: 94%
# No Mask: 83%
#
# FPS:11.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 95%
# No Mask: 94%
# Mask: 77%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 99%
# No Mask: 90%
# Mask: 70%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 95%
# No Mask: 92%
# No Mask: 71%
# Mask: 70%
#
# FPS:12.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 97%
#
# FPS:12.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 97%
# No Mask: 62%
#
# FPS:12.5 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# No Mask: 96%
# No Mask: 75%
#
# FPS:12.5 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 98%
# No Mask: 94%
# Mask: 81%
#
# FPS:12.5 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 93%
# No Mask: 88%
# Mask: 92%
#
# FPS:12.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 72%
# Mask: 92%
#
# FPS:12.5 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 85%
# Mask: 96%
#
# FPS:12.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 87%
# Mask: 96%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 84%
# Mask: 98%
#
# FPS:12.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# Mask: 99%
# Mask: 92%
#
# FPS:12.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# Mask: 100%
# Mask: 93%
#
# FPS:12.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 92%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 75%
# Mask: 100%
# Mask: 71%
#
# FPS:12.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 75%
# Mask: 100%
# Mask: 73%
#
# FPS:12.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:11.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# Mask: 99%
# Mask: 86%
#
# FPS:11.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# Mask: 100%
# Mask: 82%
#
# FPS:11.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 66%
# No Mask: 63%
# Mask: 99%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 69%
# No Mask: 64%
# Mask: 99%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 100%
# Mask: 66%
# Mask: 66%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 99%
# Mask: 84%
#
# FPS:11.6 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 85%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 79%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 91%
# No Mask: 75%
# Mask: 96%
# Mask: 93%
#
# FPS:11.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 90%
# No Mask: 74%
# Mask: 96%
# Mask: 93%
#
# FPS:12.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 91%
# No Mask: 86%
# Mask: 77%
#
# FPS:12.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 99%
# No Mask: 92%
# Mask: 61%
#
# FPS:12.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 89%
# No Mask: 75%
# Mask: 88%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 82%
# Mask: 82%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 67%
# Mask: 63%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 63%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 91%
# Mask: 64%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 72%
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 84%
# Mask: 60%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 90%
# Mask: 61%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 96%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 96%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 98%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 75%
# Mask: 98%
#
# FPS:12.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 77%
# No Mask: 71%
# Mask: 100%
# Mask: 62%
#
# FPS:12.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 78%
# Mask: 100%
# Mask: 61%
#
# FPS:12.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# Mask: 98%
#
# FPS:12.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# Mask: 98%
#
# FPS:12.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 78%
# No Mask: 75%
# Mask: 97%
# Mask: 83%
#
# FPS:12.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 72%
# Mask: 100%
# Mask: 68%
#
# FPS:12.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 78%
# Mask: 99%
#
# FPS:12.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 87%
# Mask: 67%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 70%
# Mask: 98%
# Mask: 90%
# Mask: 90%
# Mask: 85%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 69%
# Mask: 98%
# Mask: 92%
# Mask: 92%
# Mask: 84%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 61%
# Mask: 99%
# Mask: 95%
# Mask: 73%
# Mask: 68%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 64%
# Mask: 97%
# Mask: 93%
# Mask: 62%
#
# FPS:13.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# No Mask: 70%
# Mask: 98%
# Mask: 98%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 78%
# No Mask: 73%
# Mask: 97%
# Mask: 89%
# Mask: 83%
# Mask: 63%
#
# FPS:13.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 78%
# No Mask: 69%
# Mask: 100%
# Mask: 94%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 79%
# No Mask: 75%
# Mask: 100%
# Mask: 94%
#
# FPS:13.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 99%
# Mask: 94%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# Mask: 100%
# Mask: 94%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# Mask: 100%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# Mask: 100%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# Mask: 100%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 100%
#
# FPS:12.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 84%
# Mask: 100%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# Mask: 100%
# Mask: 93%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 77%
# No Mask: 69%
# Mask: 100%
# Mask: 92%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 84%
# No Mask: 74%
# Mask: 100%
# Mask: 96%
#
# FPS:12.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 92%
# Mask: 98%
#
# FPS:13.0 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 93%
# Mask: 98%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 92%
#
# FPS:13.0 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 83%
# No Mask: 63%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# No Mask: 85%
# Mask: 93%
#
# FPS:13.0 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# No Mask: 79%
# Mask: 89%
#
# FPS:12.8 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
# Mask: 100%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# No Mask: 61%
# Mask: 100%
#
# FPS:12.8 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# No Mask: 84%
# Mask: 100%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 87%
# Mask: 99%
#
# FPS:12.8 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 85%
# No Mask: 77%
# Mask: 100%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 96%
# No Mask: 78%
# Mask: 99%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# No Mask: 86%
# Mask: 98%
#
# FPS:12.8 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 93%
# No Mask: 84%
# Mask: 98%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# No Mask: 90%
# Mask: 100%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 97%
# No Mask: 82%
# No Mask: 71%
# Mask: 100%
#
# FPS:13.0 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 94%
# No Mask: 84%
# No Mask: 71%
# Mask: 91%
#
# FPS:12.9 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# No Mask: 90%
# No Mask: 81%
# No Mask: 70%
#
# FPS:13.1 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 89%
# No Mask: 77%
#
# FPS:13.0 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 89%
# No Mask: 81%
#
# FPS:13.1 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 69%
#
# FPS:13.0 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# No Mask: 86%
#
# FPS:13.1 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 92%
# No Mask: 78%
#
# FPS:13.0 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 85%
# No Mask: 68%
# No Mask: 65%
#
# FPS:13.1 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 79%
# No Mask: 65%
#
# FPS:13.0 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 80%
# No Mask: 62%
#
# FPS:12.8 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 99%
# No Mask: 88%
#
# FPS:12.5 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 94%
# No Mask: 67%
#
# FPS:12.4 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 67%
#
# FPS:12.1 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
#
# FPS:11.8 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 61%
#
# FPS:11.6 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 61%
#
# FPS:11.7 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 83%
# No Mask: 78%
#
# FPS:11.5 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 85%
# No Mask: 84%
#
# FPS:11.4 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 89%
#
# FPS:11.1 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 78%
#
# FPS:10.8 	 AVG_FPS:12.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 73%
#
# FPS:11.1 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 68%
#
# FPS:10.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 61%
#
# FPS:10.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 83%
# No Mask: 79%
#
# FPS:10.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 83%
# No Mask: 80%
# No Mask: 78%
# No Mask: 67%
#
# FPS:11.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 87%
# No Mask: 68%
#
# FPS:11.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 87%
# No Mask: 76%
#
# FPS:11.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 89%
# No Mask: 78%
# No Mask: 61%
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# No Mask: 84%
# No Mask: 82%
#
# FPS:11.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 82%
# No Mask: 71%
#
# FPS:11.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 86%
#
# FPS:10.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# No Mask: 87%
# No Mask: 83%
#
# FPS:10.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask:
	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 97%
# No Mask: 92%
# No Mask: 89%
# No Mask: 72%
# No Mask: 65%
#
# FPS:9.7 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 93%
# No Mask: 91%
# Mask: 75%
#
# FPS:9.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 79%
# No Mask: 67%
# No Mask: 65%
# Mask: 72%
#
# FPS:9.4 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 77%
# Mask: 96%
#
# FPS:9.3 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 90%
#
# FPS:9.2 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 91%
#
# FPS:9.3 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 78%
# Mask: 84%
#
# FPS:9.5 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 68%
# Mask: 96%
#
# FPS:9.8 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 77%
# Mask: 88%
# Mask: 82%
#
# FPS:10.0 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 81%
# Mask: 98%
#
# FPS:10.3 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 81%
# No Mask: 73%
# No Mask: 65%
# Mask: 79%
#
# FPS:10.7 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 81%
# No Mask: 76%
# No Mask: 64%
# Mask: 80%
#
# FPS:10.9 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# No Mask: 85%
# No Mask: 75%
# No Mask: 63%
#
# FPS:11.0 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# No Mask: 89%
# No Mask: 79%
# Mask: 61%
#
# FPS:11.0 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 95%
# No Mask: 91%
# No Mask: 87%
# Mask: 75%
#
# FPS:10.7 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 83%
# No Mask: 70%
# Mask: 88%
#
# FPS:10.4 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 89%
# No Mask: 82%
# Mask: 82%
#
# FPS:10.3 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 90%
# No Mask: 81%
# Mask: 86%
#
# FPS:10.0 	 AVG_FPS:9.4
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# No Mask: 87%
# No Mask: 78%
#
# FPS:10.2 	 AVG_FPS:9.4
#
#  cvWriteFrame
# ...
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 95%
# No Mask: 73%
#
# FPS:11.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 95%
# No Mask: 81%
#
# FPS:11.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 69%
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# Mask: 85%
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 100%
# No Mask: 96%
# Mask: 80%
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 98%
# No Mask: 67%
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 86%
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 87%
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 96%
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 95%
#
# FPS:11.9 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 61%
#
# FPS:12.0 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 95%
# Mask: 79%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 94%
# Mask: 97%
# Mask: 72%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 62%
# Mask: 97%
# Mask: 91%
#
# FPS:12.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 85%
# No Mask: 74%
# Mask: 99%
#
# FPS:12.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No Mask: 86%
# No Mask: 81%
# Mask: 96%
# Mask: 95%
#
# FPS:12.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 81%
# Mask: 94%
# Mask: 65%
#
# FPS:12.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# No Mask: 89%
# No Mask: 87%
# Mask: 99%
# Mask: 81%
#
# FPS:12.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# No Mask: 90%
# No Mask: 88%
# Mask: 99%
# Mask: 86%
#
# FPS:12.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 82%
# No Mask: 62%
# Mask: 97%
# Mask: 95%
#
# FPS:12.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 89%
# No Mask: 83%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 91%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 73%
# Mask: 94%
# Mask: 92%
#
# FPS:12.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 77%
# Mask: 99%
# Mask: 95%
#
# FPS:12.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 87%
# Mask: 99%
# Mask: 94%
#
# FPS:12.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 78%
# Mask: 94%
# Mask: 78%
#
# FPS:12.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 76%
# Mask: 98%
# Mask: 79%
#
# FPS:12.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# No Mask: 71%
# Mask: 98%
# Mask: 81%
#
# FPS:12.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# Mask: 99%
# Mask: 87%
#
# FPS:12.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# Mask: 100%
# Mask: 99%
#
# FPS:12.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# Mask: 100%
# Mask: 99%
#
# FPS:12.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 81%
# Mask: 100%
# Mask: 99%
#
# FPS:13.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# Mask: 100%
# Mask: 98%
#
# FPS:13.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 68%
# Mask: 100%
# Mask: 99%
#
# FPS:12.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask:

#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 97%
# No Mask: 73%
# No Mask: 67%
#
# FPS:12.3 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 99%
# No Mask: 63%
#
# FPS:12.4 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# No Mask: 73%
#
# FPS:12.4 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 97%
# No Mask: 72%
# Mask: 62%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 67%
#
# FPS:12.6 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 80%
# No Mask: 65%
#
# FPS:12.8 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 64%
# No Mask: 62%
#
# FPS:12.7 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 82%
# No Mask: 75%
#
# FPS:12.8 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 89%
#
# FPS:12.9 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# Mask: 89%
#
# FPS:13.0 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 77%
# No Mask: 69%
#
# FPS:12.9 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 64%
# Mask: 98%
# Mask: 87%
#
# FPS:13.1 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# Mask: 95%
# Mask: 73%
#
# FPS:13.0 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# Mask: 96%
#
# FPS:13.2 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 80%
# Mask: 91%
#
# FPS:13.0 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 68%
# No Mask: 62%
# Mask: 94%
#
# FPS:13.2 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 75%
# Mask: 99%
#
# FPS:13.1 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 79%
# Mask: 99%
#
# FPS:13.3 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 76%
# No Mask: 67%
# Mask: 99%
#
# FPS:13.2 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 65%
# No Mask: 62%
# Mask: 95%
#
# FPS:13.3 	 AVG_FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 63%
# Mask: 99%
#
# FPS:13.3 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 69%
# Mask: 99%
#
# FPS:13.3 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 80%
# Mask: 100%
#
# FPS:13.2 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# Mask: 100%
#
# FPS:13.4 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 75%
# No Mask: 64%
# Mask: 99%
#
# FPS:13.0 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 83%
# No Mask: 79%
# No Mask: 67%
# Mask: 99%
#
# FPS:12.6 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 93%
# No Mask: 73%
# No Mask: 68%
# Mask: 82%
#
# FPS:12.2 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 95%
# No Mask: 75%
# No Mask: 72%
# Mask: 92%
#
# FPS:11.9 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 86%
# No Mask: 66%
# Mask: 92%
#
# FPS:12.0 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 81%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 91%
# Mask: 100%
#
# FPS:12.0 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 88%
# No Mask: 80%
# Mask: 100%
#
# FPS:12.1 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 67%
# Mask: 100%
#
# FPS:12.1 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 62%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 61%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 66%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 81%
# Mask: 100%
#
# FPS:12.1 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:12.3 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 69%
#
# FPS:12.5 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 72%
#
# FPS:12.5 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.6 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 92%
#
# FPS:12.6 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 81%
# No Mask: 71%
#
# FPS:12.6 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 84%
# No Mask: 72%
#
# FPS:12.6 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 90%
#
# FPS:12.5 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 90%
#
# FPS:12.5 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 96%
# No Mask: 85%
# No Mask: 75%
# No Mask: 65%
#
# FPS:12.4 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 97%
# No Mask: 94%
# No Mask: 87%
# No Mask: 64%
#
# FPS:12.7 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 85%
#
# FPS:12.5 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 90%
# No Mask: 89%
#
# FPS:12.7 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 93%
# No Mask: 87%
# No Mask: 73%
#
# FPS:12.7 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 94%
# No Mask: 86%
# No Mask: 74%
#
# FPS:12.9 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
# No Mask: 92%
# No Mask: 89%
# No Mask: 69%
#
# FPS:12.8 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 87%
# No Mask: 84%
# No Mask: 76%
#
# FPS:12.9 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 94%
# No Mask: 81%
#
# FPS:12.9 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 98%
# No Mask: 64%
#
# FPS:12.9 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 71%
#
# FPS:12.8 	 AVG_FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 74%
#
# FPS:13.0 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 87%
# No Mask: 83%
#
# FPS:12.8 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No Mask: 98%
# No Mask: 90%
# No Mask: 72%
#
# FPS:12.9 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No Mask: 100%
# No Mask: 89%
# No Mask: 86%
#
# FPS:13.0 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No Mask: 99%
#
# FPS:13.0 	 AVG_FPS:12.2
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.
